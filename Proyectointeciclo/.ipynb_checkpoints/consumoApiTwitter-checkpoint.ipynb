# %% [markdown]
# ## Universidad Politecnica Salesiana
# #### Materia: Inteligencia artificial 1
# #### Estudiante: Angel Jadan
# ###### Fecha: 14/12/2020

# %%
import tweepy
import json, csv, sys

consumer_key = "rF0agXMR0fUu58HGg75OZGeRQ"
consumer_secret = "VpduZzn2ZufMjGrPhKQhzOnpzrfw47LdJjuk7IG9nbubTNuTkL"
access_token = "309077981-FEp6yFVY9uTimDwCYxcoLamgCuQ7bFTapYk7lLne"
access_token_secret = "tVacsM1EndkpyKy9gDnkskxtK2s3PKH6sCRi4XH7qmAeZ"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

#Obtner datos de mi usuario
data = api.me()
print(json.dumps(data._json, indent=2))
# Out:
# {
#   "id": 309077981,
#   "id_str": "309077981",
#   "name": "Angel",
#   "screen_name": "Angel_Jad11",
#   "location": "",
#   "profile_location": null,
#   "description": "",
#   "url": null,
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "protected": true,
#   "followers_count": 16,
#   "friends_count": 229,
#   "listed_count": 0,
#   "created_at": "Wed Jun 01 14:01:03 +0000 2011",
#   "favourites_count": 16,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 19,
#   "lang": null,
#   "status": {
#     "created_at": "Tue Oct 25 19:47:18 +0000 2016",
#     "id": 791003221028380674,
#     "id_str": "791003221028380674",
#     "text": "Don't miss the Eclipse Che virtual conference on Tuesday, November 15, 2016 @eclipse_che #CheConf2016",
#     "truncated": false,
#     "entities": {
#       "hashtags": [
#         {
#           "text": "CheConf2016",
#           "indices": [
#             89,
#             101
#           ]
#         }
#       ],
#       "symbols": [],
#       "user_mentions": [
#         {
#           "screen_name": "eclipse_che",
#           "name": "Eclipse Che",
#           "id": 3255961525,
#           "id_str": "3255961525",
#           "indices": [
#             76,
#             88
#           ]
#         }
#       ],
#       "urls": []
#     },
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 0,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "en"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "1A1B1F",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme9/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme9/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1809435769/yo_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1809435769/yo_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/309077981/1607373871",
#   "profile_link_color": "2FC2EF",
#   "profile_sidebar_border_color": "181A1E",
#   "profile_sidebar_fill_color": "252429",
#   "profile_text_color": "666666",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none",
#   "suspended": false,
#   "needs_phone_verification": false
# }

# %%
#para obtener datos de otro usuario

data = api.get_user("ecuarauz")
print(json.dumps(data._json, indent=2))
# Out:
# {
#   "id": 235712666,
#   "id_str": "235712666",
#   "name": "Andr\u00e9s Arauz",
#   "screen_name": "ecuarauz",
#   "location": "Ecuador",
#   "profile_location": null,
#   "description": "Patriota. Dem\u00f3crata. Progresista Candidato a la Presidencia del Ecuador Nunca me niego a un ceviche Jipijapa \ud83c\uddea\ud83c\udde8        \u00danete al WikiPlan, el plan de todos\ud83d\udc47\ud83c\udffc",
#   "url": "https://t.co/s4SNTQTEO4",
#   "entities": {
#     "url": {
#       "urls": [
#         {
#           "url": "https://t.co/s4SNTQTEO4",
#           "expanded_url": "http://andresarauz.ec/plandegobierno",
#           "display_url": "andresarauz.ec/plandegobierno",
#           "indices": [
#             0,
#             23
#           ]
#         }
#       ]
#     },
#     "description": {
#       "urls": []
#     }
#   },
#   "protected": false,
#   "followers_count": 53674,
#   "friends_count": 2508,
#   "listed_count": 114,
#   "created_at": "Sat Jan 08 22:33:43 +0000 2011",
#   "favourites_count": 3955,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": true,
#   "statuses_count": 14597,
#   "lang": null,
#   "status": {
#     "created_at": "Mon Dec 07 21:13:48 +0000 2020",
#     "id": 1336056340138127364,
#     "id_str": "1336056340138127364",
#     "text": "RT @MashiRafael: Los socialcristianos, due\u00f1os de junta electoral de Gal\u00e1pagos y tramposos como siempre, eliminaron a Leopoldo Bucheli y a n\u2026",
#     "truncated": false,
#     "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#         {
#           "screen_name": "MashiRafael",
#           "name": "Rafael Correa",
#           "id": 209780362,
#           "id_str": "209780362",
#           "indices": [
#             3,
#             15
#           ]
#         }
#       ],
#       "urls": []
#     },
#     "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "retweeted_status": {
#       "created_at": "Mon Dec 07 06:22:27 +0000 2020",
#       "id": 1335832021441114112,
#       "id_str": "1335832021441114112",
#       "text": "Los socialcristianos, due\u00f1os de junta electoral de Gal\u00e1pagos y tramposos como siempre, eliminaron a Leopoldo Buchel\u2026 https://t.co/NBzZxL8PYa",
#       "truncated": true,
#       "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [],
#         "urls": [
#           {
#             "url": "https://t.co/NBzZxL8PYa",
#             "expanded_url": "https://twitter.com/i/web/status/1335832021441114112",
#             "display_url": "twitter.com/i/web/status/1\u2026",
#             "indices": [
#               117,
#               140
#             ]
#           }
#         ]
#       },
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": true,
#       "quoted_status_id": 1335642699471392768,
#       "quoted_status_id_str": "1335642699471392768",
#       "retweet_count": 647,
#       "favorite_count": 1452,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "es"
#     },
#     "is_quote_status": true,
#     "quoted_status_id": 1335642699471392768,
#     "quoted_status_id_str": "1335642699471392768",
#     "retweet_count": 647,
#     "favorite_count": 0,
#     "favorited": false,
#     "retweeted": false,
#     "lang": "es"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1311149963057999873/REnQf__g_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1311149963057999873/REnQf__g_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/235712666/1601686608",
#   "profile_link_color": "4A913C",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": false,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": true,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
# }

# %%
# Para mostrar los seguidores
data = api.followers(screen_name="ecuarauz")

for user in data:
    print(json.dumps(user._json, indent=2))
# Out:
# [User(_api=<tweepy.api.API object at 0x0000018CE4827A60>, _json={'id': 1564526342, 'id_str': '1564526342', 'name': 'Scarlett', 'screen_name': 'dianap_juradito', 'location': '', 'description': '😉', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 53, 'friends_count': 658, 'listed_count': 0, 'created_at': 'Wed Jul 03 01:26:05 +0000 2013', 'favourites_count': 1075, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 207, 'lang': None, 'status': {'created_at': 'Sat Dec 05 04:27:09 +0000 2020', 'id': 1335078229212848128, 'id_str': '1335078229212848128', 'text': '@abdalabucaram un corrupto es aceptado para ser candidato a la asamblea. Y no dejan que @AbAlvaroNoboa sea candidat… https://t.co/s604JWjSal', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'abdalabucaram', 'name': 'Abdala Bucaram Ortiz', 'id': 151635175, 'id_str': '151635175', 'indices': [0, 14]}, {'screen_name': 'AbAlvaroNoboa', 'name': 'Alvaro Noboa', 'id': 4049194557, 'id_str': '4049194557', 'indices': [88, 102]}], 'urls': [{'url': 'https://t.co/s604JWjSal', 'expanded_url': 'https://twitter.com/i/web/status/1335078229212848128', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 151635175, 'in_reply_to_user_id_str': '151635175', 'in_reply_to_screen_name': 'abdalabucaram', 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': True, 'quoted_status_id': 1335074252643594244, 'quoted_status_id_str': '1335074252643594244', 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'es'}, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1236493797850259458/ynCkK8DU_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1236493797850259458/ynCkK8DU_normal.jpg', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'live_following': False, 'follow_request_sent': False, 'notifications': False, 'muting': False, 'blocking': False, 'blocked_by': False, 'translator_type': 'none'}, id=1564526342, id_str='1564526342', name='Scarlett', screen_name='dianap_juradito', location='', description='😉', url=None, entities={'description': {'urls': []}}, protected=False, followers_count=53, friends_count=658, listed_count=0, created_at=datetime.datetime(2013, 7, 3, 1, 26, 5), favourites_count=1075, utc_offset=None, time_zone=None, geo_enabled=True, verified=False, statuses_count=207, lang=None, status=Status(_api=<tweepy.api.API object at 0x0000018CE4827A60>, _json={'created_at': 'Sat Dec 05 04:27:09 +0000 2020', 'id': 1335078229212848128, 'id_str': '1335078229212848128', 'text': '@abdalabucaram un corrupto es aceptado para ser candidato a la asamblea. Y no dejan que @AbAlvaroNoboa sea candidat… https://t.co/s604JWjSal', 'truncated': True, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'abdalabucaram', 'name': 'Abdala Bucaram Ortiz', 'id': 151635175, 'id_str': '151635175', 'indices': [0, 14]}, {'screen_name': 'AbAlvaroNoboa', 'name': 'Alvaro Noboa', 'id': 4049194557, 'id_str': '4049194557', 'indices': [88, 102]}], 'urls': [{'url': 'https://t.co/s604JW ...
# 'for user in data:\n    print(json.dumps(user._json, indent=2))'

# %%
print(type(data))
# Out:
# <class 'tweepy.models.ResultSet'>

# %%
#Numero de usuarios mostrados por la api
data = api.followers(screen_name="ecuarauz")
print(len(data))

# %% [markdown]
# La API de twitter solo permite mostrar 20, que es una paginacion.
#
# Para mostrar mas datos usamos la tweepy.Cursor(), para ver mas datos.

# %%
#Para ver los seguidores Pasamos un metodo, no llamamos ningun metodo, el creeen_name=""<- es los datos que van dentro del metodo puesto.

datos = ""

for user in tweepy.Cursor(api.followers, screen_name="ecuarauz").items(100):
    #print(json.dumps(user._json, indent=2))
    datos =datos + json.dumps(user._json, indent=2)
    
    #datos = json.dumps(user._json, indent=2)

output = csv.writer(sys.stdout)
output.writerow(data[0].keys())

for row in data:
    output.writerow(row.values())

#print(len(tweepy.Cursor(api.followers, screen_name="ecuarauz").items(100)))

# %%
#Para ver amigos del usuario.
for user in tweepy.Cursor(api.friends, screen_name="ecuarauz").items(50):
    print(json.dumps(user._json, indent=2))

# %% [markdown]
# tweet_mode <- espara mostrar todo el tweet

# %%
#Para ver timeline
for tweet in tweepy.Cursor(api.user_timeline, screen_name="ecuarauz", tweet_mode="extended").items(1):
    print(json.dumps(tweet._json, indent=2))
# Out:
# {
#   "created_at": "Mon Dec 07 21:13:48 +0000 2020",
#   "id": 1336056340138127364,
#   "id_str": "1336056340138127364",
#   "full_text": "RT @MashiRafael: Los socialcristianos, due\u00f1os de junta electoral de Gal\u00e1pagos y tramposos como siempre, eliminaron a Leopoldo Bucheli y a n\u2026",
#   "truncated": false,
#   "display_text_range": [
#     0,
#     140
#   ],
#   "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [
#       {
#         "screen_name": "MashiRafael",
#         "name": "Rafael Correa",
#         "id": 209780362,
#         "id_str": "209780362",
#         "indices": [
#           3,
#           15
#         ]
#       }
#     ],
#     "urls": []
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#     "id": 235712666,
#     "id_str": "235712666",
#     "name": "Andr\u00e9s Arauz",
#     "screen_name": "ecuarauz",
#     "location": "Ecuador",
#     "description": "Patriota. Dem\u00f3crata. Progresista Candidato a la Presidencia del Ecuador Nunca me niego a un ceviche Jipijapa \ud83c\uddea\ud83c\udde8        \u00danete al WikiPlan, el plan de todos\ud83d\udc47\ud83c\udffc",
#     "url": "https://t.co/s4SNTQTEO4",
#     "entities": {
#       "url": {
#         "urls": [
#           {
#             "url": "https://t.co/s4SNTQTEO4",
#             "expanded_url": "http://andresarauz.ec/plandegobierno",
#             "display_url": "andresarauz.ec/plandegobierno",
#             "indices": [
#               0,
#               23
#             ]
#           }
#         ]
#       },
#       "description": {
#         "urls": []
#       }
#     },
#     "protected": false,
#     "followers_count": 53674,
#     "friends_count": 2508,
#     "listed_count": 114,
#     "created_at": "Sat Jan 08 22:33:43 +0000 2011",
#     "favourites_count": 3955,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "verified": true,
#     "statuses_count": 14597,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "000000",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme5/bg.gif",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme5/bg.gif",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1311149963057999873/REnQf__g_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1311149963057999873/REnQf__g_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/235712666/1601686608",
#     "profile_link_color": "4A913C",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": false,
#     "has_extended_profile": false,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": true,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#     "created_at": "Mon Dec 07 06:22:27 +0000 2020",
#     "id": 1335832021441114112,
#     "id_str": "1335832021441114112",
#     "full_text": "Los socialcristianos, due\u00f1os de junta electoral de Gal\u00e1pagos y tramposos como siempre, eliminaron a Leopoldo Bucheli y a nuestras listas 1. \nEsto es FRAUDE:\nHicimos acuerdo con Ol\u00edmpido Garc\u00eda, listas 19, quien ser\u00e1 del bloque de la Revoluci\u00f3n Ciudadana.\n#EnGal\u00e1pagosTodoMenosLa6 https://t.co/T4H7Q3FYEt",
#     "truncated": false,
#     "display_text_range": [
#       0,
#       279
#     ],
#     "entities": {
#       "hashtags": [
#         {
#           "text": "EnGal\u00e1pagosTodoMenosLa6",
#           "indices": [
#             255,
#             279
#           ]
#         }
#       ],
#       "symbols": [],
#       "user_mentions": [],
#       "urls": [
#         {
#           "url": "https://t.co/T4H7Q3FYEt",
#           "expanded_url": "https://twitter.com/MashiRafael/status/1335642699471392768",
#           "display_url": "twitter.com/MashiRafael/st\u2026",
#           "indices": [
#             280,
#             303
#           ]
#         }
#       ]
#     },
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "in_reply_to_screen_name": null,
#     "user": {
#       "id": 209780362,
#       "id_str": "209780362",
#       "name": "Rafael Correa",
#       "screen_name": "MashiRafael",
#       "location": "Ecuador",
#       "description": "Expresidente de la Rep\u00fablica del Ecuador.",
#       "url": "https://t.co/rZJb5eRQUM",
#       "entities": {
#         "url": {
#           "urls": [
#             {
#               "url": "https://t.co/rZJb5eRQUM",
#               "expanded_url": "http://economiaenbicicleta.com",
#               "display_url": "economiaenbicicleta.com",
#               "indices": [
#                 0,
#                 23
#               ]
#             }
#           ]
#         },
#         "description": {
#           "urls": []
#         }
#       },
#       "protected": false,
#       "followers_count": 3739796,
#       "friends_count": 23,
#       "listed_count": 7966,
#       "created_at": "Fri Oct 29 22:35:33 +0000 2010",
#       "favourites_count": 570,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 62614,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "D5DD4B",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1275341483986554880/B_GTwYDj_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1275341483986554880/B_GTwYDj_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/209780362/1603838471",
#       "profile_link_color": "1B95E0",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "EFEFEF",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": true,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#     },
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": true,
#     "quoted_status_id": 1335642699471392768,
#     "quoted_status_id_str": "1335642699471392768",
#     "quoted_status_permalink": {
#       "url": "https://t.co/T4H7Q3FYEt",
#       "expanded": "https://twitter.com/MashiRafael/status/1335642699471392768",
#       "display": "twitter.com/MashiRafael/st\u2026"
#     },
#     "quoted_status": {
#       "created_at": "Sun Dec 06 17:50:09 +0000 2020",
#       "id": 1335642699471392768,
#       "id_str": "1335642699471392768",
#       "full_text": "Eliminaci\u00f3n de candidatos de UNES en Gal\u00e1pagos vulner\u00f3 garant\u00edas constitucionales. VIDEO | https://t.co/Z41fmifwkS https://t.co/VJVY1uzQgM",
#       "truncated": false,
#       "display_text_range": [
#         0,
#         138
#       ],
#       "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "user_mentions": [],
#         "urls": [
#           {
#             "url": "https://t.co/Z41fmifwkS",
#             "expanded_url": "http://Confirmado.net",
#             "display_url": "Confirmado.net",
#             "indices": [
#               91,
#               114
#             ]
#           },
#           {
#             "url": "https://t.co/VJVY1uzQgM",
#             "expanded_url": "https://confirmado.net/2020/12/06/eliminacion-de-candidatos-de-unes-en-galapagos-vulnero-garantias-constitucionales-video/",
#             "display_url": "confirmado.net/2020/12/06/eli\u2026",
#             "indices": [
#               115,
#               138
#             ]
#           }
#         ]
#       },
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#         "id": 209780362,
#         "id_str": "209780362",
#         "name": "Rafael Correa",
#         "screen_name": "MashiRafael",
#         "location": "Ecuador",
#         "description": "Expresidente de la Rep\u00fablica del Ecuador.",
#         "url": "https://t.co/rZJb5eRQUM",
#         "entities": {
#           "url": {
#             "urls": [
#               {
#                 "url": "https://t.co/rZJb5eRQUM",
#                 "expanded_url": "http://economiaenbicicleta.com",
#                 "display_url": "economiaenbicicleta.com",
#                 "indices": [
#                   0,
#                   23
#                 ]
#               }
#             ]
#           },
#           "description": {
#             "urls": []
#           }
#         },
#         "protected": false,
#         "followers_count": 3739796,
#         "friends_count": 23,
#         "listed_count": 7966,
#         "created_at": "Fri Oct 29 22:35:33 +0000 2010",
#         "favourites_count": 570,
#         "utc_offset": null,
#         "time_zone": null,
#         "geo_enabled": true,
#         "verified": true,
#         "statuses_count": 62614,
#         "lang": null,
#         "contributors_enabled": false,
#         "is_translator": false,
#         "is_translation_enabled": false,
#         "profile_background_color": "D5DD4B",
#         "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#         "profile_background_tile": false,
#         "profile_image_url": "http://pbs.twimg.com/profile_images/1275341483986554880/B_GTwYDj_normal.jpg",
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/1275341483986554880/B_GTwYDj_normal.jpg",
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/209780362/1603838471",
#         "profile_link_color": "1B95E0",
#         "profile_sidebar_border_color": "FFFFFF",
#         "profile_sidebar_fill_color": "EFEFEF",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "has_extended_profile": false,
#         "default_profile": false,
#         "default_profile_image": false,
#         "following": true,
#         "follow_request_sent": false,
#         "notifications": false,
#         "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 344,
#       "favorite_count": 656,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "es"
#     },
#     "retweet_count": 644,
#     "favorite_count": 1444,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "lang": "es"
#   },
#   "is_quote_status": true,
#   "quoted_status_id": 1335642699471392768,
#   "quoted_status_id_str": "1335642699471392768",
#   "quoted_status_permalink": {
#     "url": "https://t.co/T4H7Q3FYEt",
#     "expanded": "https://twitter.com/MashiRafael/status/1335642699471392768",
#     "display": "twitter.com/MashiRafael/st\u2026"
#   },
#   "retweet_count": 644,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "es"
# }

# %% [markdown]
# Para buscar tweets

# %%
#q <- es la busqueda por texto el tweet que se desee
for tweet in tweepy.Cursor(api.search, q="andres arauz", tweet_mode = "extended").items(10):
    '''Para mostrar todos los datos'''
    print(json.dumps(tweet._json, indent=3))
    
    '''
        Para mostrar solo el texto
        print(tweet._json["full_text"])
    '''
# Out:
# {
#    "created_at": "Tue Dec 08 00:07:09 +0000 2020",
#    "id": 1336099962921361409,
#    "id_str": "1336099962921361409",
#    "full_text": "@modz_andres @AP_Kost @isidroromero_c Y el bobo lerdo lelo de Arauz que es una eminencia???? si ni hablar bien ni portar c\u00e9dula propia puede ese bobo HIJODEPUTA",
#    "truncated": false,
#    "display_text_range": [
#       38,
#       160
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "modz_andres",
#             "name": "Carlos Calder\u00f3n",
#             "id": 898933658702282755,
#             "id_str": "898933658702282755",
#             "indices": [
#                0,
#                12
#             ]
#          },
#          {
#             "screen_name": "AP_Kost",
#             "name": "Kost",
#             "id": 364454445,
#             "id_str": "364454445",
#             "indices": [
#                13,
#                21
#             ]
#          },
#          {
#             "screen_name": "isidroromero_c",
#             "name": "Isidro Romero Carbo",
#             "id": 1029751086192762881,
#             "id_str": "1029751086192762881",
#             "indices": [
#                22,
#                37
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": 1336005460550443012,
#    "in_reply_to_status_id_str": "1336005460550443012",
#    "in_reply_to_user_id": 898933658702282755,
#    "in_reply_to_user_id_str": "898933658702282755",
#    "in_reply_to_screen_name": "modz_andres",
#    "user": {
#       "id": 1231685940994859009,
#       "id_str": "1231685940994859009",
#       "name": "julito maridue\u00f1a",
#       "screen_name": "juliomariduea5",
#       "location": "Machala",
#       "description": "",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 229,
#       "friends_count": 1936,
#       "listed_count": 0,
#       "created_at": "Sun Feb 23 21:03:13 +0000 2020",
#       "favourites_count": 45322,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 11228,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1335621487781425155/RYml67fS_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1335621487781425155/RYml67fS_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1231685940994859009/1582492750",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 0,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:06:17 +0000 2020",
#    "id": 1336099743567654913,
#    "id_str": "1336099743567654913",
#    "full_text": "RT @ErmelRosario: \ud83d\udc7aTONTON NOBOA QUIERE ROBAR TIERRAS A COMUNEROS\ud83d\udc79\ud83d\udc79\n#NiUnVotoALaDerecha \nSeg\u00fan los comuneros de Engabao, \u00c1lvaro Noboa, a la\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       139
#    ],
#    "entities": {
#       "hashtags": [
#          {
#             "text": "NiUnVotoALaDerecha",
#             "indices": [
#                67,
#                86
#             ]
#          }
#       ],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "ErmelRosario",
#             "name": "Ermel Rosario",
#             "id": 747575407,
#             "id_str": "747575407",
#             "indices": [
#                3,
#                16
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 1242490320455176192,
#       "id_str": "1242490320455176192",
#       "name": "Ecuador, mi pa\u00eds.",
#       "screen_name": "ecuadormipais10",
#       "location": "Ecuador",
#       "description": "Amante del progresismo justo y equitativo. Opositor a la explotaci\u00f3n laboral. Cr\u00edtico de la hipocres\u00eda. Admirador de la belleza natural de mi pa\u00eds.",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 19,
#       "friends_count": 0,
#       "listed_count": 0,
#       "created_at": "Tue Mar 24 16:36:31 +0000 2020",
#       "favourites_count": 14,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 10,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1288870068600872963/1JTBDlmH_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1288870068600872963/1JTBDlmH_normal.jpg",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Mon Dec 07 10:21:31 +0000 2020",
#       "id": 1335892187675037696,
#       "id_str": "1335892187675037696",
#       "full_text": "\ud83d\udc7aTONTON NOBOA QUIERE ROBAR TIERRAS A COMUNEROS\ud83d\udc79\ud83d\udc79\n#NiUnVotoALaDerecha \nSeg\u00fan los comuneros de Engabao, \u00c1lvaro Noboa, a la brava y a punta de bala, quiere robarles sus tierras.\nEl 1%, son ricos, que ellos voten por Noboa. 99% somos pobres, vamos  a votar, ANDR\u00c9S AR\u00c1UZ. https://t.co/1U7GviXxFc",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          267
#       ],
#       "entities": {
#          "hashtags": [
#             {
#                "text": "NiUnVotoALaDerecha",
#                "indices": [
#                   49,
#                   68
#                ]
#             }
#          ],
#          "symbols": [],
#          "user_mentions": [],
#          "urls": [],
#          "media": [
#             {
#                "id": 1335891490325880833,
#                "id_str": "1335891490325880833",
#                "indices": [
#                   268,
#                   291
#                ],
#                "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1335891490325880833/pu/img/zD-wF6VZaoOBUIJh.jpg",
#                "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1335891490325880833/pu/img/zD-wF6VZaoOBUIJh.jpg",
#                "url": "https://t.co/1U7GviXxFc",
#                "display_url": "pic.twitter.com/1U7GviXxFc",
#                "expanded_url": "https://twitter.com/ErmelRosario/status/1335892187675037696/video/1",
#                "type": "photo",
#                "sizes": {
#                   "thumb": {
#                      "w": 150,
#                      "h": 150,
#                      "resize": "crop"
#                   },
#                   "small": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   },
#                   "large": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   },
#                   "medium": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   }
#                }
#             }
#          ]
#       },
#       "extended_entities": {
#          "media": [
#             {
#                "id": 1335891490325880833,
#                "id_str": "1335891490325880833",
#                "indices": [
#                   268,
#                   291
#                ],
#                "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1335891490325880833/pu/img/zD-wF6VZaoOBUIJh.jpg",
#                "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1335891490325880833/pu/img/zD-wF6VZaoOBUIJh.jpg",
#                "url": "https://t.co/1U7GviXxFc",
#                "display_url": "pic.twitter.com/1U7GviXxFc",
#                "expanded_url": "https://twitter.com/ErmelRosario/status/1335892187675037696/video/1",
#                "type": "video",
#                "sizes": {
#                   "thumb": {
#                      "w": 150,
#                      "h": 150,
#                      "resize": "crop"
#                   },
#                   "small": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   },
#                   "large": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   },
#                   "medium": {
#                      "w": 640,
#                      "h": 368,
#                      "resize": "fit"
#                   }
#                },
#                "video_info": {
#                   "aspect_ratio": [
#                      40,
#                      23
#                   ],
#                   "duration_millis": 106398,
#                   "variants": [
#                      {
#                         "content_type": "application/x-mpegURL",
#                         "url": "https://video.twimg.com/ext_tw_video/1335891490325880833/pu/pl/H89c4kjP6UnlMe2k.m3u8?tag=10"
#                      },
#                      {
#                         "bitrate": 256000,
#                         "content_type": "video/mp4",
#                         "url": "https://video.twimg.com/ext_tw_video/1335891490325880833/pu/vid/468x270/3YBGmMJJ3FLAg-Wk.mp4?tag=10"
#                      },
#                      {
#                         "bitrate": 832000,
#                         "content_type": "video/mp4",
#                         "url": "https://video.twimg.com/ext_tw_video/1335891490325880833/pu/vid/640x368/jcOgryW19bLeTrXp.mp4?tag=10"
#                      }
#                   ]
#                },
#                "additional_media_info": {
#                   "monetizable": false
#                }
#             }
#          ]
#       },
#       "metadata": {
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 747575407,
#          "id_str": "747575407",
#          "name": "Ermel Rosario",
#          "screen_name": "ErmelRosario",
#          "location": "Guayaquil - Ecuador",
#          "description": "30 a\u00f1os como Contador P\u00fablico Ecuatoriano, Cuentas Reales Ecuador Transparente.",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 2726,
#          "friends_count": 4289,
#          "listed_count": 3,
#          "created_at": "Thu Aug 09 17:08:17 +0000 2012",
#          "favourites_count": 25945,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": true,
#          "verified": false,
#          "statuses_count": 25916,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "C0DEED",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_tile": false,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/378800000029375529/3022f23e739be92c2f32fe37707dfd61_normal.jpeg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000029375529/3022f23e739be92c2f32fe37707dfd61_normal.jpeg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/747575407/1479756203",
#          "profile_link_color": "1DA1F2",
#          "profile_sidebar_border_color": "C0DEED",
#          "profile_sidebar_fill_color": "DDEEF6",
#          "profile_text_color": "333333",
#          "profile_use_background_image": true,
#          "has_extended_profile": false,
#          "default_profile": true,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 37,
#       "favorite_count": 41,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "es"
#    },
#    "is_quote_status": false,
#    "retweet_count": 37,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:06:04 +0000 2020",
#    "id": 1336099692988469248,
#    "id_str": "1336099692988469248",
#    "full_text": "RT @biological_dr: \u201cAndr\u00e9s ARAUZ le DELEGAR\u00c1 la reactivaci\u00f3n del sector PRODUCTIVO y la recuperaci\u00f3n del EMPLEO\u201d\n\n\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83d\ude02\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       140
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "biological_dr",
#             "name": "Dr. Vintage",
#             "id": 46677008,
#             "id_str": "46677008",
#             "indices": [
#                3,
#                17
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 234931080,
#       "id_str": "234931080",
#       "name": "Desde UIO",
#       "screen_name": "tgyeuio2",
#       "location": "",
#       "description": "",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 893,
#       "friends_count": 727,
#       "listed_count": 4,
#       "created_at": "Thu Jan 06 22:58:47 +0000 2011",
#       "favourites_count": 17922,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 70386,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "EDECE9",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1334085574664318979/zGVhFsFI_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1334085574664318979/zGVhFsFI_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/234931080/1606045701",
#       "profile_link_color": "088253",
#       "profile_sidebar_border_color": "D3D2CF",
#       "profile_sidebar_fill_color": "E3E2DE",
#       "profile_text_color": "634047",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Mon Dec 07 22:53:58 +0000 2020",
#       "id": 1336081548173565953,
#       "id_str": "1336081548173565953",
#       "full_text": "\u201cAndr\u00e9s ARAUZ le DELEGAR\u00c1 la reactivaci\u00f3n del sector PRODUCTIVO y la recuperaci\u00f3n del EMPLEO\u201d\n\n\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83e\udd23\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02 https://t.co/teWOJYgDyQ",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          173
#       ],
#       "entities": {
#          "hashtags": [],
#          "symbols": [],
#          "user_mentions": [],
#          "urls": [
#             {
#                "url": "https://t.co/teWOJYgDyQ",
#                "expanded_url": "https://twitter.com/eluniversocom/status/1336050368766210055",
#                "display_url": "twitter.com/eluniversocom/\u2026",
#                "indices": [
#                   174,
#                   197
#                ]
#             }
#          ]
#       },
#       "metadata": {
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 46677008,
#          "id_str": "46677008",
#          "name": "Dr. Vintage",
#          "screen_name": "biological_dr",
#          "location": "Quito",
#          "description": "Si me sigues, te voy a seguir porque s\u00e9 que piensas como yo y compartes algo similar.  Las cosas suelen cambiar conforme crecemos en canas.",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 5257,
#          "friends_count": 2347,
#          "listed_count": 25,
#          "created_at": "Fri Jun 12 15:38:16 +0000 2009",
#          "favourites_count": 19039,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": false,
#          "verified": false,
#          "statuses_count": 35326,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "131516",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#          "profile_background_tile": true,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1301003886367571968/i-8sjRY9_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1301003886367571968/i-8sjRY9_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/46677008/1577731651",
#          "profile_link_color": "3B94D9",
#          "profile_sidebar_border_color": "000000",
#          "profile_sidebar_fill_color": "252429",
#          "profile_text_color": "666666",
#          "profile_use_background_image": true,
#          "has_extended_profile": false,
#          "default_profile": false,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": true,
#       "quoted_status_id": 1336050368766210055,
#       "quoted_status_id_str": "1336050368766210055",
#       "quoted_status": {
#          "created_at": "Mon Dec 07 20:50:05 +0000 2020",
#          "id": 1336050368766210055,
#          "id_str": "1336050368766210055",
#          "full_text": "(Entrevista) Carlos Rabascall, aspirante a la vicepresidencia, dice que Andr\u00e9s Arauz le delegar\u00e1 la reactivaci\u00f3n del sector productivo, la recuperaci\u00f3n del empleo y la equidad territorial. \u25ba https://t.co/m0gpIujtF4 https://t.co/impB8KZHCp",
#          "truncated": false,
#          "display_text_range": [
#             0,
#             214
#          ],
#          "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                {
#                   "url": "https://t.co/m0gpIujtF4",
#                   "expanded_url": "http://ow.ly/Jhqn50CEQTn",
#                   "display_url": "ow.ly/Jhqn50CEQTn",
#                   "indices": [
#                      191,
#                      214
#                   ]
#                }
#             ],
#             "media": [
#                {
#                   "id": 1336050367478571009,
#                   "id_str": "1336050367478571009",
#                   "indices": [
#                      215,
#                      238
#                   ],
#                   "media_url": "http://pbs.twimg.com/media/EoqauwOXIAE-aL2.jpg",
#                   "media_url_https": "https://pbs.twimg.com/media/EoqauwOXIAE-aL2.jpg",
#                   "url": "https://t.co/impB8KZHCp",
#                   "display_url": "pic.twitter.com/impB8KZHCp",
#                   "expanded_url": "https://twitter.com/eluniversocom/status/1336050368766210055/photo/1",
#                   "type": "photo",
#                   "sizes": {
#                      "small": {
#                         "w": 680,
#                         "h": 445,
#                         "resize": "fit"
#                      },
#                      "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                      },
#                      "large": {
#                         "w": 687,
#                         "h": 450,
#                         "resize": "fit"
#                      },
#                      "medium": {
#                         "w": 687,
#                         "h": 450,
#                         "resize": "fit"
#                      }
#                   }
#                }
#             ]
#          },
#          "extended_entities": {
#             "media": [
#                {
#                   "id": 1336050367478571009,
#                   "id_str": "1336050367478571009",
#                   "indices": [
#                      215,
#                      238
#                   ],
#                   "media_url": "http://pbs.twimg.com/media/EoqauwOXIAE-aL2.jpg",
#                   "media_url_https": "https://pbs.twimg.com/media/EoqauwOXIAE-aL2.jpg",
#                   "url": "https://t.co/impB8KZHCp",
#                   "display_url": "pic.twitter.com/impB8KZHCp",
#                   "expanded_url": "https://twitter.com/eluniversocom/status/1336050368766210055/photo/1",
#                   "type": "photo",
#                   "sizes": {
#                      "small": {
#                         "w": 680,
#                         "h": 445,
#                         "resize": "fit"
#                      },
#                      "thumb": {
#                         "w": 150,
#                         "h": 150,
#                         "resize": "crop"
#                      },
#                      "large": {
#                         "w": 687,
#                         "h": 450,
#                         "resize": "fit"
#                      },
#                      "medium": {
#                         "w": 687,
#                         "h": 450,
#                         "resize": "fit"
#                      }
#                   }
#                }
#             ]
#          },
#          "metadata": {
#             "iso_language_code": "es",
#             "result_type": "recent"
#          },
#          "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#          "in_reply_to_status_id": null,
#          "in_reply_to_status_id_str": null,
#          "in_reply_to_user_id": null,
#          "in_reply_to_user_id_str": null,
#          "in_reply_to_screen_name": null,
#          "user": {
#             "id": 8225692,
#             "id_str": "8225692",
#             "name": "El Universo",
#             "screen_name": "eluniversocom",
#             "location": "Guayaquil, Ecuador",
#             "description": "Una nueva imagen, el mismo valor y compromiso periodi\u0301stico. #LaNoticiaEsta\u0301EnElUniverso",
#             "url": "https://t.co/dbcp5ulRPv",
#             "entities": {
#                "url": {
#                   "urls": [
#                      {
#                         "url": "https://t.co/dbcp5ulRPv",
#                         "expanded_url": "http://www.eluniverso.com",
#                         "display_url": "eluniverso.com",
#                         "indices": [
#                            0,
#                            23
#                         ]
#                      }
#                   ]
#                },
#                "description": {
#                   "urls": []
#                }
#             },
#             "protected": false,
#             "followers_count": 2210876,
#             "friends_count": 2828,
#             "listed_count": 4374,
#             "created_at": "Thu Aug 16 15:08:04 +0000 2007",
#             "favourites_count": 273,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": true,
#             "statuses_count": 304653,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "054D80",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1261872658494427136/ukJfP_HT_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1261872658494427136/ukJfP_HT_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/8225692/1584933889",
#             "profile_link_color": "01385F",
#             "profile_sidebar_border_color": "FFFFFF",
#             "profile_sidebar_fill_color": "A9BCD8",
#             "profile_text_color": "000000",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": true,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none"
#          },
#          "geo": null,
#          "coordinates": null,
#          "place": null,
#          "contributors": null,
#          "is_quote_status": false,
#          "retweet_count": 43,
#          "favorite_count": 101,
#          "favorited": false,
#          "retweeted": false,
#          "possibly_sensitive": false,
#          "lang": "es"
#       },
#       "retweet_count": 11,
#       "favorite_count": 33,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "es"
#    },
#    "is_quote_status": true,
#    "quoted_status_id": 1336050368766210055,
#    "quoted_status_id_str": "1336050368766210055",
#    "retweet_count": 11,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:05:19 +0000 2020",
#    "id": 1336099503347298304,
#    "id_str": "1336099503347298304",
#    "full_text": "RT @amandaasubiar: Si nos vamos a convertir en Venezuela. Si no permiten la inscripci\u00f3n de Andr\u00e9s Ar\u00e1uz a la presidencia el mismo d\u00eda serem\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       140
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "amandaasubiar",
#             "name": "Amanda P\u00e1ez",
#             "id": 336117114,
#             "id_str": "336117114",
#             "indices": [
#                3,
#                17
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 724337746744102912,
#       "id_str": "724337746744102912",
#       "name": "Marvin Black",
#       "screen_name": "marvinblack011",
#       "location": "",
#       "description": "",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 184,
#       "friends_count": 614,
#       "listed_count": 1,
#       "created_at": "Sun Apr 24 20:42:31 +0000 2016",
#       "favourites_count": 4545,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 27119,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/724338559314989057/0LPQdmIO_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/724338559314989057/0LPQdmIO_normal.jpg",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Mon Dec 07 22:25:27 +0000 2020",
#       "id": 1336074368758280192,
#       "id_str": "1336074368758280192",
#       "full_text": "Si nos vamos a convertir en Venezuela. Si no permiten la inscripci\u00f3n de Andr\u00e9s Ar\u00e1uz a la presidencia el mismo d\u00eda seremos la Venezuela de antes de Ch\u00e1vez y el Caracazo va a quedar corto porque se arma en Ecuador y con covid. Mejor procedan como si no son lo hijueputas que son.",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          278
#       ],
#       "entities": {
#          "hashtags": [],
#          "symbols": [],
#          "user_mentions": [],
#          "urls": []
#       },
#       "metadata": {
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 336117114,
#          "id_str": "336117114",
#          "name": "Amanda P\u00e1ez",
#          "screen_name": "amandaasubiar",
#          "location": "Latinoam\u00e9rica",
#          "description": "Ecuatoriana de Guayaquil. M\u00e9dico. Investigadora. \nCorre\u00edsta. Convencida del Socialismo del Siglo XXI.",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 20643,
#          "friends_count": 5034,
#          "listed_count": 50,
#          "created_at": "Fri Jul 15 19:27:29 +0000 2011",
#          "favourites_count": 239604,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": true,
#          "verified": false,
#          "statuses_count": 158737,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "000000",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_tile": false,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1315740730074312705/NijkLQsD_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1315740730074312705/NijkLQsD_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/336117114/1602537555",
#          "profile_link_color": "94D487",
#          "profile_sidebar_border_color": "000000",
#          "profile_sidebar_fill_color": "000000",
#          "profile_text_color": "000000",
#          "profile_use_background_image": false,
#          "has_extended_profile": true,
#          "default_profile": false,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": {
#          "id": "0177bc687a9ac697",
#          "url": "https://api.twitter.com/1.1/geo/id/0177bc687a9ac697.json",
#          "place_type": "city",
#          "name": "Quito",
#          "full_name": "Quito, Ecuador",
#          "country_code": "EC",
#          "country": "Ecuador",
#          "contained_within": [],
#          "bounding_box": {
#             "type": "Polygon",
#             "coordinates": [
#                [
#                   [
#                      -78.948465999276,
#                      -0.588618000469648
#                   ],
#                   [
#                      -78.1648970044175,
#                      -0.588618000469648
#                   ],
#                   [
#                      -78.1648970044175,
#                      0.255476999458879
#                   ],
#                   [
#                      -78.948465999276,
#                      0.255476999458879
#                   ]
#                ]
#             ]
#          },
#          "attributes": {}
#       },
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 20,
#       "favorite_count": 81,
#       "favorited": false,
#       "retweeted": false,
#       "lang": "es"
#    },
#    "is_quote_status": false,
#    "retweet_count": 20,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:04:47 +0000 2020",
#    "id": 1336099366881280001,
#    "id_str": "1336099366881280001",
#    "full_text": "RT @telesurenglish: #Ecuador's leftist presidential candidate Andres Arauz @ecuarauz denounced the intention of President Lenin Moreno's ad\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       140
#    ],
#    "entities": {
#       "hashtags": [
#          {
#             "text": "Ecuador",
#             "indices": [
#                20,
#                28
#             ]
#          }
#       ],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "telesurenglish",
#             "name": "teleSUR English",
#             "id": 296005306,
#             "id_str": "296005306",
#             "indices": [
#                3,
#                18
#             ]
#          },
#          {
#             "screen_name": "ecuarauz",
#             "name": "Andr\u00e9s Arauz",
#             "id": 235712666,
#             "id_str": "235712666",
#             "indices": [
#                75,
#                84
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "en",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 833933200061718528,
#       "id_str": "833933200061718528",
#       "name": "Dray \ud83c\udf1e",
#       "screen_name": "DrayOlaya",
#       "location": "",
#       "description": "Llaqtakunaq atipayninwan, teqrimuyuta kuyuchisunchis \ud83c\uddf5\ud83c\uddea \ud83c\udff3\ufe0f\u200d\ud83c\udf08 BLM (he/him)",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 396,
#       "friends_count": 290,
#       "listed_count": 1,
#       "created_at": "Tue Feb 21 06:55:43 +0000 2017",
#       "favourites_count": 10367,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 10364,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1333618639556075527/-Iu9APFV_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1333618639556075527/-Iu9APFV_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/833933200061718528/1607231972",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Wed Dec 02 14:04:12 +0000 2020",
#       "id": 1334136288358883328,
#       "id_str": "1334136288358883328",
#       "full_text": "#Ecuador's leftist presidential candidate Andres Arauz @ecuarauz denounced the intention of President Lenin Moreno's administration to postpone the elections\u00a0so as to have more time to privatize the country's public companies. https://t.co/bccYQe6XmD",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          250
#       ],
#       "entities": {
#          "hashtags": [
#             {
#                "text": "Ecuador",
#                "indices": [
#                   0,
#                   8
#                ]
#             }
#          ],
#          "symbols": [],
#          "user_mentions": [
#             {
#                "screen_name": "ecuarauz",
#                "name": "Andr\u00e9s Arauz",
#                "id": 235712666,
#                "id_str": "235712666",
#                "indices": [
#                   55,
#                   64
#                ]
#             }
#          ],
#          "urls": [
#             {
#                "url": "https://t.co/bccYQe6XmD",
#                "expanded_url": "https://www.telesurenglish.net/news/Ecuador-Leftist-Candidate-Claims-Govt-Plans-to-Delay-Elections-20201202-0001.html",
#                "display_url": "telesurenglish.net/news/Ecuador-L\u2026",
#                "indices": [
#                   227,
#                   250
#                ]
#             }
#          ]
#       },
#       "metadata": {
#          "iso_language_code": "en",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 296005306,
#          "id_str": "296005306",
#          "name": "teleSUR English",
#          "screen_name": "telesurenglish",
#          "location": "Quito, Ecuador",
#          "description": "teleSUR English provides the best coverage of Latin America and an alternative perspective on global events. \nhttps://t.co/j672A0RsKC",
#          "url": "https://t.co/bYswj7pApA",
#          "entities": {
#             "url": {
#                "urls": [
#                   {
#                      "url": "https://t.co/bYswj7pApA",
#                      "expanded_url": "http://telesurenglish.net",
#                      "display_url": "telesurenglish.net",
#                      "indices": [
#                         0,
#                         23
#                      ]
#                   }
#                ]
#             },
#             "description": {
#                "urls": [
#                   {
#                      "url": "https://t.co/j672A0RsKC",
#                      "expanded_url": "https://www.telesurenglish.net",
#                      "display_url": "telesurenglish.net",
#                      "indices": [
#                         110,
#                         133
#                      ]
#                   }
#                ]
#             }
#          },
#          "protected": false,
#          "followers_count": 112686,
#          "friends_count": 3972,
#          "listed_count": 1877,
#          "created_at": "Tue May 10 01:28:09 +0000 2011",
#          "favourites_count": 4593,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": true,
#          "verified": false,
#          "statuses_count": 164871,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "C0DEED",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#          "profile_background_tile": false,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1280499295565877248/GMpBc2ha_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1280499295565877248/GMpBc2ha_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/296005306/1607000392",
#          "profile_link_color": "0084B4",
#          "profile_sidebar_border_color": "FFFFFF",
#          "profile_sidebar_fill_color": "DDEEF6",
#          "profile_text_color": "333333",
#          "profile_use_background_image": false,
#          "has_extended_profile": true,
#          "default_profile": false,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 16,
#       "favorite_count": 21,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "en"
#    },
#    "is_quote_status": false,
#    "retweet_count": 16,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "en"
# }
# {
#    "created_at": "Tue Dec 08 00:04:23 +0000 2020",
#    "id": 1336099269242187776,
#    "id_str": "1336099269242187776",
#    "full_text": "RT @_Illaritika: Es incre\u00edble el apoyo a Andr\u00e9s Ara\u00faz en la zona rural, de la gente del campo, de a pie, la que no est\u00e1 en redes sociales,\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       139
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "_Illaritika",
#             "name": "Alejandra\ud83c\udf37",
#             "id": 296514060,
#             "id_str": "296514060",
#             "indices": [
#                3,
#                15
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 1043275838,
#       "id_str": "1043275838",
#       "name": "Margarita Veintimilla",
#       "screen_name": "marveintimilla",
#       "location": "",
#       "description": "Esposa, madre de Gemita y Arianna, abuela de Victoria; orgullosa portovejense. Luchadora incansable por los derechos de la mujer. El amor es mi fuente de vida.",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 1272,
#       "friends_count": 432,
#       "listed_count": 1,
#       "created_at": "Fri Dec 28 22:18:14 +0000 2012",
#       "favourites_count": 12906,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": false,
#       "statuses_count": 12640,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "C0DEED",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
# ...
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 1328373240734081026,
#          "id_str": "1328373240734081026",
#          "name": "@TuiterosRcPichincha",
#          "screen_name": "TuiterosRcPich",
#          "location": "Pichincha - Quito",
#          "description": "Cuanta Oficial de Tuiteros por Ecuador - Pichincha",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 70,
#          "friends_count": 30,
#          "listed_count": 0,
#          "created_at": "Mon Nov 16 16:24:05 +0000 2020",
#          "favourites_count": 31,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": false,
#          "verified": false,
#          "statuses_count": 562,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "F5F8FA",
#          "profile_background_image_url": null,
#          "profile_background_image_url_https": null,
#          "profile_background_tile": false,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1328373352235458562/OXZW_RmO_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1328373352235458562/OXZW_RmO_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/1328373240734081026/1605545180",
#          "profile_link_color": "1DA1F2",
#          "profile_sidebar_border_color": "C0DEED",
#          "profile_sidebar_fill_color": "DDEEF6",
#          "profile_text_color": "333333",
#          "profile_use_background_image": true,
#          "has_extended_profile": false,
#          "default_profile": true,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "none"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 14,
#       "favorite_count": 26,
#       "favorited": false,
#       "retweeted": false,
#       "possibly_sensitive": false,
#       "lang": "es"
#    },
#    "is_quote_status": false,
#    "retweet_count": 14,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:02:36 +0000 2020",
#    "id": 1336098819872788480,
#    "id_str": "1336098819872788480",
#    "full_text": "RT @_Illaritika: Es incre\u00edble el apoyo a Andr\u00e9s Ara\u00faz en la zona rural, de la gente del campo, de a pie, la que no est\u00e1 en redes sociales,\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       139
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "_Illaritika",
#             "name": "Alejandra\ud83c\udf37",
#             "id": 296514060,
#             "id_str": "296514060",
#             "indices": [
#                3,
#                15
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 1247876064191426560,
#       "id_str": "1247876064191426560",
#       "name": "Diego Ayala",
#       "screen_name": "Diego_AAyala",
#       "location": "",
#       "description": "Escritor\nWriter\n.\n.\n.\nSe abrir\u00e1n las grandes alamedas por donde pase el hombre libre",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 57,
#       "friends_count": 210,
#       "listed_count": 0,
#       "created_at": "Wed Apr 08 13:18:01 +0000 2020",
#       "favourites_count": 12315,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 1538,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "F5F8FA",
#       "profile_background_image_url": null,
#       "profile_background_image_url_https": null,
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1334256402454417411/d3I3Kawn_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1334256402454417411/d3I3Kawn_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/1247876064191426560/1596866921",
#       "profile_link_color": "1DA1F2",
#       "profile_sidebar_border_color": "C0DEED",
#       "profile_sidebar_fill_color": "DDEEF6",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": true,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Mon Dec 07 17:50:03 +0000 2020",
#       "id": 1336005061873455105,
#       "id_str": "1336005061873455105",
#       "full_text": "Es incre\u00edble el apoyo a Andr\u00e9s Ara\u00faz en la zona rural, de la gente del campo, de a pie, la que no est\u00e1 en redes sociales, acabo de hablar con al menos 50 personas cabezas de hogar cuyas familias apoyar\u00e1n su candidatura \ud83d\ude4c\ud83c\udffb\ud83d\udcaa\ud83c\udffb\u2764",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          224
#       ],
#       "entities": {
#          "hashtags": [],
#          "symbols": [],
#          "user_mentions": [],
#          "urls": []
#       },
#       "metadata": {
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 296514060,
#          "id_str": "296514060",
#          "name": "Alejandra\ud83c\udf37",
#          "screen_name": "_Illaritika",
#          "location": "Quito, Ecuador",
#          "description": "Amante de la magia de la monta\u00f1a, de los sonidos del mar, de los colores de Latinoam\u00e9rica. LIGA de Quito, mercados financieros, escritura...a la izquierda \u2b05\ufe0f\u2764\ud83c\udf43",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 4414,
#          "friends_count": 3062,
#          "listed_count": 23,
#          "created_at": "Tue May 10 22:23:48 +0000 2011",
#          "favourites_count": 42648,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": true,
#          "verified": false,
#          "statuses_count": 54687,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "FF6699",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme11/bg.gif",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme11/bg.gif",
#          "profile_background_tile": true,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1322001065387110411/RL-c9ZLb_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1322001065387110411/RL-c9ZLb_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/296514060/1418429656",
#          "profile_link_color": "B40B43",
#          "profile_sidebar_border_color": "FFFFFF",
#          "profile_sidebar_fill_color": "E5507E",
#          "profile_text_color": "362720",
#          "profile_use_background_image": true,
#          "has_extended_profile": true,
#          "default_profile": false,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "regular"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 86,
#       "favorite_count": 339,
#       "favorited": false,
#       "retweeted": false,
#       "lang": "es"
#    },
#    "is_quote_status": false,
#    "retweet_count": 86,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
# {
#    "created_at": "Tue Dec 08 00:00:52 +0000 2020",
#    "id": 1336098381479948289,
#    "id_str": "1336098381479948289",
#    "full_text": "RT @_Illaritika: Es incre\u00edble el apoyo a Andr\u00e9s Ara\u00faz en la zona rural, de la gente del campo, de a pie, la que no est\u00e1 en redes sociales,\u2026",
#    "truncated": false,
#    "display_text_range": [
#       0,
#       139
#    ],
#    "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#          {
#             "screen_name": "_Illaritika",
#             "name": "Alejandra\ud83c\udf37",
#             "id": 296514060,
#             "id_str": "296514060",
#             "indices": [
#                3,
#                15
#             ]
#          }
#       ],
#       "urls": []
#    },
#    "metadata": {
#       "iso_language_code": "es",
#       "result_type": "recent"
#    },
#    "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#       "id": 327408649,
#       "id_str": "327408649",
#       "name": "manuel pesantes",
#       "screen_name": "manuelpesantes",
#       "location": "Machala EL ORO ECUADOR",
#       "description": "Hay una fuerza motriz mas poderoza que el vapor, la electricidad  y la energia atomica que es:\n LA VOLUNTAD",
#       "url": null,
#       "entities": {
#          "description": {
#             "urls": []
#          }
#       },
#       "protected": false,
#       "followers_count": 91,
#       "friends_count": 326,
#       "listed_count": 0,
#       "created_at": "Fri Jul 01 14:30:55 +0000 2011",
#       "favourites_count": 4932,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": false,
#       "statuses_count": 10242,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "642D8B",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme10/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1251343720043200512/ocjABRfg_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1251343720043200512/ocjABRfg_normal.jpg",
#       "profile_link_color": "9900FF",
#       "profile_sidebar_border_color": "65B0DA",
#       "profile_sidebar_fill_color": "7AC3EE",
#       "profile_text_color": "3D1957",
#       "profile_use_background_image": true,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "retweeted_status": {
#       "created_at": "Mon Dec 07 17:50:03 +0000 2020",
#       "id": 1336005061873455105,
#       "id_str": "1336005061873455105",
#       "full_text": "Es incre\u00edble el apoyo a Andr\u00e9s Ara\u00faz en la zona rural, de la gente del campo, de a pie, la que no est\u00e1 en redes sociales, acabo de hablar con al menos 50 personas cabezas de hogar cuyas familias apoyar\u00e1n su candidatura \ud83d\ude4c\ud83c\udffb\ud83d\udcaa\ud83c\udffb\u2764",
#       "truncated": false,
#       "display_text_range": [
#          0,
#          224
#       ],
#       "entities": {
#          "hashtags": [],
#          "symbols": [],
#          "user_mentions": [],
#          "urls": []
#       },
#       "metadata": {
#          "iso_language_code": "es",
#          "result_type": "recent"
#       },
#       "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#       "in_reply_to_status_id": null,
#       "in_reply_to_status_id_str": null,
#       "in_reply_to_user_id": null,
#       "in_reply_to_user_id_str": null,
#       "in_reply_to_screen_name": null,
#       "user": {
#          "id": 296514060,
#          "id_str": "296514060",
#          "name": "Alejandra\ud83c\udf37",
#          "screen_name": "_Illaritika",
#          "location": "Quito, Ecuador",
#          "description": "Amante de la magia de la monta\u00f1a, de los sonidos del mar, de los colores de Latinoam\u00e9rica. LIGA de Quito, mercados financieros, escritura...a la izquierda \u2b05\ufe0f\u2764\ud83c\udf43",
#          "url": null,
#          "entities": {
#             "description": {
#                "urls": []
#             }
#          },
#          "protected": false,
#          "followers_count": 4414,
#          "friends_count": 3062,
#          "listed_count": 23,
#          "created_at": "Tue May 10 22:23:48 +0000 2011",
#          "favourites_count": 42648,
#          "utc_offset": null,
#          "time_zone": null,
#          "geo_enabled": true,
#          "verified": false,
#          "statuses_count": 54687,
#          "lang": null,
#          "contributors_enabled": false,
#          "is_translator": false,
#          "is_translation_enabled": false,
#          "profile_background_color": "FF6699",
#          "profile_background_image_url": "http://abs.twimg.com/images/themes/theme11/bg.gif",
#          "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme11/bg.gif",
#          "profile_background_tile": true,
#          "profile_image_url": "http://pbs.twimg.com/profile_images/1322001065387110411/RL-c9ZLb_normal.jpg",
#          "profile_image_url_https": "https://pbs.twimg.com/profile_images/1322001065387110411/RL-c9ZLb_normal.jpg",
#          "profile_banner_url": "https://pbs.twimg.com/profile_banners/296514060/1418429656",
#          "profile_link_color": "B40B43",
#          "profile_sidebar_border_color": "FFFFFF",
#          "profile_sidebar_fill_color": "E5507E",
#          "profile_text_color": "362720",
#          "profile_use_background_image": true,
#          "has_extended_profile": true,
#          "default_profile": false,
#          "default_profile_image": false,
#          "following": false,
#          "follow_request_sent": false,
#          "notifications": false,
#          "translator_type": "regular"
#       },
#       "geo": null,
#       "coordinates": null,
#       "place": null,
#       "contributors": null,
#       "is_quote_status": false,
#       "retweet_count": 86,
#       "favorite_count": 339,
#       "favorited": false,
#       "retweeted": false,
#       "lang": "es"
#    },
#    "is_quote_status": false,
#    "retweet_count": 86,
#    "favorite_count": 0,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
# }
