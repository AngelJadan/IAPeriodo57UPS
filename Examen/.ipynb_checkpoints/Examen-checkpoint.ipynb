# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo, RelationshipFrom)

config.DATABASE_URL = 'bolt://neo4j:Angel2019@localhost:7687'

class Asambleista(StructuredNode):
    nameCan = StringProperty(unique_index=True)
    partido = StringProperty(unique_index=True)
class Noticia(StructuredNode):
    idNoti = UniqueIdProperty()
    date = StringProperty(unique_index=False)
    messaje = StringProperty(unique_index=False)
    link = StringProperty(unique_index=False)
    asambleista = RelationshipTo('Asambleista' , 'NOTICIA_DE')

# %%
#Datos url google, seccion noticias

start_url = ['https://www.google.com/search?q=Juan+Cristobal+Lloret+Valdivieso&client=opera-gx&sxsrf=ALeKk01v5ZkhcF5Qa9-if9xu7dKafPl_Hg:1607584958950&source=lnms&tbm=nws&sa=X&ved=2ahUKEwiYoLLT8MLtAhUMn-AKHY9cBdUQ_AUoA3oECAQQBQ&biw=529&bih=579',
             'https://www.google.com/search?q=Juan+Cristobal+Lloret+Valdivieso&client=opera-gx&tbm=nws&sxsrf=ALeKk03m2X06qkfIAt064ZbGGIixHyrnMw:1607585227518&ei=y83RX5mGH8K5gge3xbCQCA&start=10&sa=N&ved=0ahUKEwjZl7rT8cLtAhXCnOAKHbciDIIQ8tMDCIQB&biw=1239&bih=579&dpr=1.5'
            ]
#print(nurl)
asamb = Asambleista(nameCan='Juan Cristobal Lloret Valdivieso', partido='UNES').save()

c=1
print("Contenido de pagina google candidato asambleista Juan Lloret")
for ur in start_url:
    url = ur
    respuesta = requests.get(
        url,
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
        }
    )
    contenido_web = BeautifulSoup(respuesta.text, 'lxml')
    noticias = contenido_web.find('div', attrs={'class':'eqAnXb'})
    lin = noticias.findChildren('div',attrs={'class':'dbsr'})
    
    for enlace in lin:
        enla=str(enlace.a.get('href'))
        
        men = ""
        sms1 = enlace.findChildren('div', attrs={'class':'yJHHTd'})    
        for message1 in sms1:
            sms2 = message1.findChildren('div', attrs={'class':'Y3v8qd'})
            men = str(sms2)    

        #Para limpiar las etiquetas
        cleantext = BeautifulSoup(men, "lxml").text
        mens1 = cleantext.strip("[").strip("]")

        #print("Fecha")
        fecha1=str(enlace.findChildren('span', attrs={'class':'WG9SHc'}))
        fecclear = BeautifulSoup(fecha1, "lxml").text
        #Variable de fecha
        fecha2 = fecclear.strip("[").strip("]")
        
        
        noticia =  Noticia(idNoti=c,date=fecha2, messaje=mens1, link=enla).save()
        noticia.asambleista.connect(asamb)
        print("Datos guardados")
        c=c+1
# Out:
# Contenido de pagina google candidato asambleista Juan Lloret
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados

# %%
# Datos candidato presidente ecosia.
print("Contenido de pagina ecosia de candidato Andres Arauz")
cont=0
for i in range(5):
    print('Item')
    print(cont)
    url = 'https://www.ecosia.org/news?q=Andres%20Arauz&p='+str(cont)
    respuesta = requests.get(
        url,
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
        }
    )
    myData = []
    contenido_web = BeautifulSoup(respuesta.text, 'lxml')
    noticias = contenido_web.find('div', attrs={'class':'layout'})
    sections = noticias.findChildren('div', attrs={'class':'result__body'})
    cont=cont+1
    for section in sections:
        #Codigo para grafo
        codigo = "unesecosia"+str(c)
        #print('Link:')
        link = section.a.get('href')
        clink = BeautifulSoup(str(link), "lxml").text
        
        #Link limpio en variable
        clink = str(clink)
               
        hora = section.findChildren('time', attrs={'class':'news-result__date'})
        chora = BeautifulSoup(str(hora), "lxml").text
        #Hora limpia en variable
        schora = (chora.strip("[").strip("]")).rstrip().lstrip()
    
        sms = section.findChildren('div', attrs={'class':'result__content-inner'})
        csms = BeautifulSoup(str(sms), "lxml").text
        
        #Mensaje limpio en variable
        scsms =(csms.strip("[").strip("]").strip('"')).rstrip().lstrip()
        
        noticia =  Noticia(idNoti=c,date=schora, messaje=scsms, link=clink).save()
        noticia.asambleista.connect(asamb)
        print("Datos guardados")
        c=c+1
# Out:
# Contenido de pagina ecosia de candidato Andres Arauz
# Item
# 0
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Item
# 1
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Item
# 2
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Datos guardados
# Item
# 3
# Datos guardados
# Datos guardados
# Datos guardados
# Item
# 4
# Datos guardados
# Datos guardados
# Datos guardados

# %%
cont=1
print("Contenido de pagina ask.")
for i in range(3):
    print('Page')
    print(cont)
    url = 'https://www.ask.com/web?o=0&l=dir&qo=pagination&q=andres%20arauz%20noticias&qsrc=998&page='+str(cont)
    respuesta = requests.get(
        url,
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
        }
    )
    contenido_web = BeautifulSoup(respuesta.text, 'lxml')
    noticias = contenido_web.find('div', attrs={'PartialSearchResults-body'})
    seccion = noticias.findChildren('div', attrs={'class': 'PartialSearchResults-item'})
    
    for item in seccion:
        print("Item")
        
        tit = str(item.find('div').a)
        titulo = BeautifulSoup(tit, "lxml").text
        print("Pagina: "+titulo)
        
        link = str(item.find('div').a.get("href"))
        print("Link: "+link)
        
        sms = str(item.find('p', attrs = {'class':'PartialSearchResults-item-abstract'}))
        sms1 = BeautifulSoup(sms, "lxml").text
        print("Mensaje: "+sms1)
        
        noticia =  Noticia(idNoti=c,date=titulo, messaje=sms1, link=link).save()
        noticia.asambleista.connect(asamb)
        print("Datos guardados")
        c=c+1
    cont=cont+1
# Out:
# Contenido de pagina ask.
# Page
# 1
# Item
# Pagina: Andrés Arauz: Indulto a Rafael Correa no será necesario porque los ...
# Link: https://www.eluniverso.com/noticias/2021/01/04/nota/9267190/elecciones-presidenciales-ecuador-2021-andres-arauz-unes
# Mensaje: 4 Ene 2021 ... Política | Noticias | El Universo ...
# Datos guardados
# Item
# Pagina: Andrés Arauz Galarza: Noticias, fotos y videos de Andrés Arauz ...
# Link: https://www.eluniverso.com/tema/andres-arauz
# Mensaje: Noticias, análisis, entrevistas, fotos y videos sobre Andrés Arauz Galarza en
# personajes de El Universo.
# Datos guardados
# Item
# Pagina: Noticias archivos - Andrés Arauz
# Link: https://andresarauz.ec/category/noticias/
# Mensaje: Andrés Arauz hace un llamado a la comunidad internacional a mantenerse
# vigilante del proceso electoral en Ecuador. Home; /; Noticias ...
# Datos guardados
# Item
# Pagina: Andrés Arauz, el economista que quiere emular a Rafael Correa
# ...

# %%
#Datos de noticias google, candidato presidente Andres Arauz
print("Datos de noticias google, candidato presidente Andres Arauz")
item=0
con=1
cont=0
for i in range(19):
    url =  url = 'https://www.google.com/search?q=andres+arauz&tbm=nws&ei=PYHaX8CJCcGJ5wLIt5CgCA&start='+str(cont)+'&sa=N&ved=0ahUKEwiAnJ30vdPtAhXBxFkKHcgbBIQ4jAEQ8tMDCKAB&biw=1280&bih=610&dpr=1.5'
    respuesta = requests.get(
        url,
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
        }
    )
    contenido_web = BeautifulSoup(respuesta.text, 'lxml')
    noticias = contenido_web.find('div', attrs={'class':'eqAnXb'})
    lin = noticias.findChildren('div',attrs={'class':'dbsr'})
    cont=cont+10
    item=item
    print("Enlace: ")
    print(url)
    for enlace in lin:
        item=item+1
        enla=str(enlace.a.get('href'))
        print("Enlace")
        print(enla)
        #print('Mensaje')
        men = ""
        sms1 = enlace.findChildren('div', attrs={'class':'yJHHTd'})    
        for message1 in sms1:
            sms2 = message1.findChildren('div', attrs={'class':'Y3v8qd'})
            men = str(sms2)    

        #Para limpiar las etiquetas
        print("Mensaje")
        cleantext = BeautifulSoup(men, "lxml").text
        mens1 = cleantext.strip("[").strip("]")
        #print(mens1)

        print("Fecha")
        fecha1=str(enlace.findChildren('span', attrs={'class':'WG9SHc'}))
        fecclear = BeautifulSoup(fecha1, "lxml").text
        #Variable de fecha
        fecha2 = fecclear.strip("[").strip("]")
        print(fecha2)
        
        noticia =  Noticia(idNoti=c,date=fecha2, messaje=mens1, link=enla).save()
        noticia.asambleista.connect(asamb)
        print("Datos guardados")
        
        print(c)
        c= c + 1
        
    con=con+1
# Out:
# Datos de noticias google, candidato presidente Andres Arauz
# Enlace:
# https://www.google.com/search?q=andres+arauz&tbm=nws&ei=PYHaX8CJCcGJ5wLIt5CgCA&start=0&sa=N&ved=0ahUKEwiAnJ30vdPtAhXBxFkKHcgbBIQ4jAEQ8tMDCKAB&biw=1280&bih=610&dpr=1.5
# Enlace
# https://www.eluniverso.com/noticias/2021/01/04/nota/9267190/elecciones-presidenciales-ecuador-2021-andres-arauz-unes
# Mensaje
# Fecha
# Hace 1 semana
# Datos guardados
# 70
# Enlace
# https://www.eltelegrafo.com.ec/noticias/politica/3/andres-arauz-debate-presidencial
# Mensaje
# Fecha
# hace 6 días
# Datos guardados
# 71
# Enlace
# https://www.primicias.ec/noticias/firmas/arauz-yaku-rehuyen-debate-correa-aparece-campana-enfurece-ecuador/
# Mensaje
# Fecha
# hace 21 horas
# Datos guardados
# 72
# Enlace
# https://www.primicias.ec/noticias/politica/candidato-andres-arauz-contagiado-covid/
# Mensaje
# Fecha
# Hace 3 semanas
# Datos guardados
# 73
# Enlace
# ...
