&biw=1239&bih=579&dpr=1.5',
             'https://www.google.com/search?q=andres+arauz&client=opera-gx&tbm=nws&sxsrf=ALeKk01ZG833aOyMyMH7QebpV86NX13dRw:1607586271938&ei=39HRX5n4OK3n_Qbx8qGIBw&start=130&sa=N&ved=0ahUKEwjZ47zF9cLtAhWtc98KHXF5CHE4eBDy0wMImgE&biw=1239&bih=579&dpr=1.5',
             'https://www.google.com/search?q=andres+arauz&client=opera-gx&tbm=nws&sxsrf=ALeKk01oBIMOxlUA_Ny-G1vM9EwzmTw5xA:1607586279722&ei=59HRX_vSK4SQ_QabioXYAw&start=140&sa=N&ved=0ahUKEwi74pfJ9cLtAhUESN8KHRtFATs4ggEQ8tMDCJkB&biw=1239&bih=579&dpr=1.5',
             'https://www.google.com/search?q=andres+arauz&client=opera-gx&tbm=nws&sxsrf=ALeKk01qfPDv9GeBuzhPAzaUygcEHgtlsw:1607586286548&ei=7tHRX4X_IPK0ggeL6ZCYDQ&start=150&sa=N&ved=0ahUKEwiFrrjM9cLtAhVymuAKHYs0BNM4jAEQ8tMDCJoB&biw=1239&bih=579&dpr=1.5',
             'https://www.google.com/search?q=andres+arauz&client=opera-gx&tbm=nws&sxsrf=ALeKk00eS9FQUz7ajgoBLrBqVIo340DSKg:1607586293338&ei=9dHRX-2OFOmg_QbOxbzYAw&start=160&sa=N&ved=0ahUKEwit3dbP9cLtAhVpUN8KHc4iDzs4lgEQ8tMDCJoB&biw=1239&bih=579&dpr=1.5'
            ]
            
"""


#print(nurl)
item=0
con=1
cont=0
for i in range(19):
    url =  url = 'https://www.google.com/search?q=andres+arauz&tbm=nws&ei=PYHaX8CJCcGJ5wLIt5CgCA&start='+str(cont)+'&sa=N&ved=0ahUKEwiAnJ30vdPtAhXBxFkKHcgbBIQ4jAEQ8tMDCKAB&biw=1280&bih=610&dpr=1.5'
    respuesta = requests.get(
        url,
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'
        }
    )
    contenido_web = BeautifulSoup(respuesta.text, 'lxml')
    noticias = contenido_web.find('div', attrs={'class':'eqAnXb'})
    lin = noticias.findChildren('div',attrs={'class':'dbsr'})
    cont=cont+10
    item=item
    print("Enlace: ")
    print(url)
    for enlace in lin:
        item=item+1
        enla=str(enlace.a.get('href'))
        print("Enlace")
        print(enla)
        #print('Mensaje')
        men = ""
        sms1 = enlace.findChildren('div', attrs={'class':'yJHHTd'})    
        for message1 in sms1:
            sms2 = message1.findChildren('div', attrs={'class':'Y3v8qd'})
            men = str(sms2)    

        #Para limpiar las etiquetas
        print("Mensaje")
        cleantext = BeautifulSoup(men, "lxml").text
        mens1 = cleantext.strip("[").strip("]")
        print(mens1)

        print("Fecha")
        fecha1=str(enlace.findChildren('span', attrs={'class':'WG9SHc'}))
        fecclear = BeautifulSoup(fecha1, "lxml").text
        #Variable de fecha
        fecha2 = fecclear.strip("[").strip("]")
        print(fecha2)
        c= c + 1
        print(c)
    con=con+1
# Out:
# Enlace:
# https://www.google.com/search?q=andres+arauz&tbm=nws&ei=PYHaX8CJCcGJ5wLIt5CgCA&start=0&sa=N&ved=0ahUKEwiAnJ30vdPtAhXBxFkKHcgbBIQ4jAEQ8tMDCKAB&biw=1280&bih=610&dpr=1.5
# Enlace
# https://www.elcomercio.com/actualidad/arauz-vigilancia-internacional-candidatura-cne.html
# Mensaje
# El aspirante por el correísmo a la Presidencia de Ecuador, Andrés Arauz,
# habla durante un conversatorio con periodistas hoy, en Quito ...
# Fecha
# Hace 2 semanas
# 11
# Enlace
# https://confirmado.net/2020/12/01/andres-arauz-armar-a-la-poblacion-no-es-la-salida-a-la-inseguridad/
# Mensaje
# Para Andrés Arauz, candidato a la Presidencia de Ecuador por la Lista 1,
# dotar de armas a la publicación no es una salida para frenar los ...
# Fecha
# Hace 2 semanas
# 12
# Enlace
# https://www.eldiario.ec/noticias-manabi-ecuador/524889-andres-arauz-pide-vigilancia-tras-retraso-en-aprobacion-de-su-candidatura-a-la-presidencia-de-ecuador/
# Mensaje
# ...
