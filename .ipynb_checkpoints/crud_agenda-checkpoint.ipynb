# %%
class Operadora:
    
    def __init__(self, nombre, numero):
        self.nombre    = nombre
        self.numero    = numero
    def getNombre(self):
        return str(self.nombre)
    def getNumero(self):
        return str(self.numero)
class Persona:
    lista = dict()
    
    def __init__(self, nombre, apellido, cedula, nacimiento):
        
        self.nombre    = nombre
        self.apellido  = apellido
        self.cedula    = cedula
        self.nacimiento= nacimiento
        
        #self.operadora = Operadora
                
    def getNombre(self):
        return str(self.nombre)
    def getApellido(self):
        return str(self.apellido)
    def getCedula(self):
        return str(self.cedula)
    def getNacimiento(self):
        return str(self.nacimiento)
    
    def guardar(Persona):
        nombre      = Persona.getNombre()
        apellido    = Persona.getApellido()
        cedula      = Persona.getCedula()
        nacimiento  = Persona.getNacimiento()
#        print(persona)
        dic[nombre]={nombre,apellido,cedula, nacimiento}
    def buscar(nombre):
        print(lista.get(nombre))

# %%
from tkinter import *
from tkinter import ttk

ventana = Tk()
ventana.geometry("500x500")
ventana.title("CRUD agenda")
ventana.resizable(0,0)

txnombre=StringVar()
nombre = Label(ventana,text="Nombre", width=10).place(x=10, y=10)
txtnombre = ttk.Entry(ventana, textvariable=txnombre).place(x=100,y=10)

txapellido=StringVar()
apellido = Label(ventana,text="Apellido", width=10).place(x=10, y=40)
txtapellido = ttk.Entry(ventana, textvariable=txapellido).place(x=100,y=40)

txdireccion=StringVar()
direccion = Label(ventana,text="Cedula", width=10).place(x=10, y=70)
txtdireccion = ttk.Entry(ventana,textvariable=txdireccion).place(x=100,y=70)

txtelefono=StringVar()
telefono = Label(ventana,text="Nacimiento", width=10).place(x=10, y=100)
txttelefono = ttk.Entry(ventana,textvariable=txtelefono).place(x=100,y=100)


#def listado(nombre, apellido, direccion, telefono):
    


def guardar():
    nombre = txnombre.get()
    apellido=txapellido.get()
    direccion=txdireccion.get()
    telefono=txtelefono.get()
    
    persona = Persona(nombre, apellido, direccion, telefono)
    persona.guardar()
    




Button(ventana, text="Guardar", command=guardar).place(x=100, y=150)
Button(ventana, text="Editar").place(x=160, y=150)
Button(ventana, text="Eliminar").place(x=210, y=150)
Button(ventana, text="Buscar").place(x=270, y=150)


ventana.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\EstAngelMesiasJadanC\anaconda3\lib\tkinter\__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-60-fa70b8b65840>", line 37, in guardar
#     persona.guardar()
#   File "<ipython-input-59-12deb5f1d64b>", line 37, in guardar
#     lista[nombre]={nombre,apellido,cedula, nacimiento}
# NameError: name 'lista' is not defined
