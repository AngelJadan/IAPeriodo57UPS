# %%
import csv
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo, RelationshipFrom)

# %%
text = open ('C:/Users/EstAngelMesiasJadanC/Desktop/claves.txt','r')
datos = (text.read()).split(sep=",")
user = datos[0]
pasw = datos[1]
print(user)
print(pasw)

config.DATABASE_URL = 'bolt://neo4j:'+pasw+'@localhost:7687'
# Out:
# neo4j
# Angel2019

# %%
class Ciudad(StructuredNode):
    nombre = StringProperty(unique_index=False)
    lugar = StringProperty(unique_index=False)
    lat = StringProperty(unique_index=False)
    lon = StringProperty(unique_index=False)
# Out:
# ---------------------------------------------------------------------------
# ClassAlreadyDefined                       Traceback (most recent call last)
# <ipython-input-129-19e586b389d7> in <module>
# ----> 1 class Ciudad(StructuredNode):
#       2     nombre = StringProperty(unique_index=False)
#       3     lugar = StringProperty(unique_index=False)
#       4     lat = StringProperty(unique_index=False)
#       5     lon = StringProperty(unique_index=False)
#
# ~\anaconda3\lib\site-packages\neomodel\core.py in __new__(mcs, name, bases, namespace)
#     205                 db._NODE_CLASS_REGISTRY[label_set] = cls
#     206             else:
# --> 207                 raise ClassAlreadyDefined(cls, db._NODE_CLASS_REGISTRY)
#     208
#     209         return cls
#
# ClassAlreadyDefined: Class __main__.Ciudad with labels Ciudad already defined:
# {frozenset({'Lugar'}): <class '__main__.Lugar'>, frozenset({'Ciudad'}): <class '__main__.Ciudad'>}

# %%
lug = Ciudad(nombre='Duran', lugar='Duran', lat='-21449', lon='-02646').save()
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# <ipython-input-130-086093e15248> in <module>
# ----> 1 lug = Ciudad(nombre='Duran', lugar='Duran', lat='-21449', lon='-02646').save()
#
# ~\anaconda3\lib\site-packages\neomodel\hooks.py in hooked(self)
#      12         fn_name = getattr(fn, 'func_name', fn.__name__)
#      13         _exec_hook('pre_' + fn_name, self)
# ---> 14         val = fn(self)
#      15         _exec_hook('post_' + fn_name, self)
#      16         return val
#
# ~\anaconda3\lib\site-packages\neomodel\core.py in save(self)
#     559                 self.__class__.__name__))
#     560         else:  # create
# --> 561             self.id = self.create(self.__properties__)[0].id
#     562         return self
#
# ~\anaconda3\lib\site-packages\neomodel\core.py in create(cls, *props, **kwargs)
#     356         results = []
#     357         for item in [cls.deflate(p, obj=_UnsavedNode(), skip_empty=True) for p in props]:
# --> 358             node, _ = db.cypher_query(query, {'create_params': item})
#     359             results.extend(node[0])
#     360
#
# ~\anaconda3\lib\site-packages\neomodel\util.py in wrapper(self, *args, **kwargs)
#      32
#      33         if not _db.url:
# ---> 34             _db.set_connection(config.DATABASE_URL)
#      35         return func(self, *args, **kwargs)
#      36
#
# ~\anaconda3\lib\site-packages\neomodel\util.py in set_connection(self, url)
#      97                              " got {0}".format(url))
#      98
# ---> 99         self.driver = GraphDatabase.driver(u.scheme + '://' + hostname,
#     100                                            auth=basic_auth(username, password),
#     101                                            encrypted=config.ENCRYPTED_CONNECTION,
#
# ~\anaconda3\lib\site-packages\neo4j\__init__.py in driver(cls, uri, auth, **config)
#     181
#     182         if driver_type == DRIVER_BOLT:
# --> 183             return cls.bolt_driver(parsed.netloc, auth=auth, **config)
#     184         elif driver_type == DRIVER_NEO4j:
#     185             routing_context = parse_routing_context(parsed.query)
#
# ~\anaconda3\lib\site-packages\neo4j\__init__.py in bolt_driver(cls, target, auth, **config)
#     194
#     195         try:
# --> 196             return BoltDriver.open(target, auth=auth, **config)
#     197         except (BoltHandshakeError, BoltSecurityError) as error:
#     198             from neo4j.exceptions import ServiceUnavailable
#
# ~\anaconda3\lib\site-packages\neo4j\__init__.py in open(cls, target, auth, **config)
#     357         address = cls.parse_target(target)
#     358         pool_config, default_workspace_config = Config.consume_chain(config, PoolConfig, WorkspaceConfig)
# --> 359         pool = BoltPool.open(address, auth=auth, pool_config=pool_config, workspace_config=default_workspace_config)
#     360         return cls(pool, default_workspace_config)
#     361
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in open(cls, address, auth, pool_config, workspace_config, routing_context)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 531         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     532         pool.release(*seeds)
#     533         return pool
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in <listcomp>(.0)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
# --> 531         seeds = [pool.acquire() for _ in range(pool_config.init_size)]
#     532         pool.release(*seeds)
#     533         return pool
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in acquire(self, access_mode, timeout, database)
#     543     def acquire(self, access_mode=None, timeout=None, database=None):
#     544         # The access_mode and database is not needed for a direct connection, its just there for consistency.
# --> 545         return self._acquire(self.address, timeout)
#     546
#     547
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in _acquire(self, address, timeout)
#     407                     timeout = min(self.pool_config.connection_timeout, time_remaining())
#     408                     try:
# --> 409                         connection = self.opener(address, timeout)
#     410                     except ServiceUnavailable:
#     411                         self.remove(address)
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in opener(addr, timeout)
#     526
#     527         def opener(addr, timeout):
# --> 528             return Bolt.open(addr, auth=auth, timeout=timeout, routing_context=routing_context, **pool_config)
#     529
#     530         pool = cls(opener, pool_config, workspace_config, routing_context, address)
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     225             s.shutdown(SHUT_RDWR)
#     226             s.close()
# --> 227             raise error
#     228
#     229         return connection
#
# ~\anaconda3\lib\site-packages\neo4j\io\__init__.py in open(cls, address, auth, timeout, routing_context, **pool_config)
#     220
#     221         try:
# --> 222             connection.hello()
#     223         except Exception as error:
#     224             log.debug("[#%04X]  C: <CLOSE> %s", s.getsockname()[1], str(error))
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4x1.py in hello(self)
#     146         self._append(b"\x01", (headers,), response=InitResponse(self, on_success=self.server_info._update_metadata))
#     147         self.send_all()
# --> 148         self.fetch_all()
#     149
#     150     def run(self, query, parameters=None, mode=None, bookmarks=None, metadata=None, timeout=None, db=None, **handlers):
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4x1.py in fetch_all(self)
#     416             response = self.responses[0]
#     417             while not response.complete:
# --> 418                 detail_delta, summary_delta = self.fetch_message()
#     419                 detail_count += detail_delta
#     420                 summary_count += summary_delta
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4x1.py in fetch_message(self)
#     351             log.debug("[#%04X]  S: FAILURE %r", self.local_port, summary_metadata)
#     352             try:
# --> 353                 response.on_failure(summary_metadata or {})
#     354             except (ServiceUnavailable, DatabaseUnavailable):
#     355                 if self.pool:
#
# ~\anaconda3\lib\site-packages\neo4j\io\_bolt4x1.py in on_failure(self, metadata)
#     569         message = metadata.get("message", "Connection initialisation failed")
#     570         if code == "Neo.ClientError.Security.Unauthorized":
# --> 571             raise AuthError(message)
#     572         else:
#     573             raise ServiceUnavailable(message)
#
# AuthError: {code: None} {message: None}

# %%
results = []
with open('Datosduran.csv') as File:
    reader = csv.DictReader(File)
    for row in reader:
        results.append(row)
    #print(results)
for ite in results:
    ro = ite['Nombre;Lugar;Tipo;Latitud;Longitud']
    arr = ro.split(sep=';')
    print('Nombre> '+arr[0])
    print('Lugar> '+arr[1])
    print('Tipo> '+arr[2])
    print('Latitud> '+arr[3])
    print('Longitud> '+arr[4])
    print("....")
# Out:
# Nombre> duran
# Lugar> Duran
# Tipo> Ciudad
# Latitud> 0
# Longitud> 0
# ....
# Nombre> parquesanjose
# Lugar> Parque San Jose
# Tipo> Parque
# Latitud> -2.1639611
# Longitud> -79.81846
# ....
# Nombre> parquecdla.modular
# Lugar> Parque cdla. Modular
# Tipo> Parque
# Latitud> -2.1639611
# Longitud> -79.81846
# ....
# Nombre> parquecdla.16deoctubre
# Lugar> Parque cdla. 16 de octubre
# Tipo> Parque
# Latitud> -2.1563901
# Longitud> -79.8199956
# ....
# Nombre> parqueacuaticoheroesnacionales
# Lugar> Parque Acuatico Heroes Nacionales
# Tipo> Parque
# Latitud> -2.1647219
# Longitud> -79.8284987
# ....
# Nombre> parquedelaprimavera1
# Lugar> Parque de la primavera 1
# Tipo> Parque
# Latitud> -2.1679811
# Longitud> -79.846609
# ....
# Nombre> parquerecreacionalcdla.rioguayas
# Lugar> Parque recreacional Cdla. Rio Guayas
# Tipo> Parque
# Latitud> -2.1679811
# Longitud> -79.846609
# ....
# Nombre> parquealamadre
# Lugar> Parque a la Madre
# Tipo> Parque
# Latitud> -2.1757861
# Longitud> -79.8507289
# ....
# Nombre> parquecolinasdelvalle
# Lugar> Parque Colinas Del Valle
# Tipo> Parque
# Latitud> -2.1757861
# Longitud> -79.8507289
# ....
# Nombre> parqueprimavera
# Lugar> Parque Primavera
# Tipo> Parque
# Latitud> -2.1812753
# Longitud> -79.8506859
# ....
# Nombre> skatemunicipaldeduranprima.2
# Lugar> Skate Municipal De Durán prima. 2
# Tipo> Parque
# Latitud> -2.1812753
# Longitud> -79.8506859
# ....
# Nombre> parqueecologicoduran
# Lugar> Parque Ecologico Duran
# Tipo> Parque
# Latitud> -2.1812753
# Longitud> -79.8506859
# ....
# Nombre> parqueprimavera2
# Lugar> Parque Primavera 2
# Tipo> Parque
# Latitud> -2.1812753
# Longitud> -79.8506859
# ....
# Nombre> canteracerrogrande
# Lugar> Cantera cerro grande
# Tipo> Parque
# Latitud> -2.1780517
# Longitud> -79.8027142
# ....
# Nombre> primerparque4taet.recreo
# Lugar> Primer Parque 4ta Et. Recreo
# Tipo> Parque
# Latitud> -2.1727774
# Longitud> -79.8003684
# ....
# Nombre> canchasdeindor
# Lugar> Canchas de Indor
# Tipo> Parque
# Latitud> -2.1709738
# Longitud> -79.8011604
# ....
# Nombre> parquedela5taetapa
# Lugar> Parque De La 5ta Etapa
# Tipo> Parque
# Latitud> -2.1709738
# Longitud> -79.8011604
# ....
# Nombre> parqueacuaticoheroesnacionales
# Lugar> Parque Acuatico Heroes Nacionales
# Tipo> Parque
# Latitud> -2.1670004
# Longitud> -79.8317903
# ....
# Nombre> areasverdes
# Lugar> Areas verdes
# Tipo> Reserva Natual
# Latitud> -2.1842531
# Longitud> -79.8450631
# ....
# Nombre> parque
# Lugar> Parque
# Tipo> Parque
# Latitud> -2.1747908
# Longitud> -79.8304363
# ....
# Nombre> hotellaríadurán
# Lugar> Hotel La Ría Durán
# Tipo> Hotel
# Latitud> -2.168413
# Longitud> -79.8491938
# ....
# Nombre> iglesiadediosduran
# Lugar> Iglesia de dios duran
# Tipo> Iglesia
# Latitud> -2.1766861
# Longitud> -79.8032343
# ....
# Nombre> iglesiacatólicasantamaríareinadelasfamilias
# Lugar> Iglesia Católica Santa María Reina de las Familias
# Tipo> Iglesia
# Latitud> -2.190073
# Longitud> -79.8256406
# ....
# Nombre> laiglesiadejesucristosudcapillaponton
# Lugar> La Iglesia de Jesucristo SUD Capilla Ponton
# Tipo> Iglesia
# Latitud> -2.1711368
# Longitud> -79.8536137
# ....
# Nombre> iglesiaevangelica"laresurreccion"
# Lugar> "Iglesia Evangelica ""La Resurreccion"""
# Tipo> Iglesia
# Latitud> -2.1616151
# Longitud> -79.828621
# ....
# Nombre> iglesiaevangélicaatriosdealabanzas
# Lugar> Iglesia Evangélica Atrios de Alabanzas
# Tipo> Iglesia
# Latitud> -2.1616582
# Longitud> -79.8256654
# ....
# Nombre> iglesiacatólicainmaculadaconcepción
# Lugar> Iglesia Católica Inmaculada Concepción
# Tipo> Iglesia
# Latitud> -2.1631054
# Longitud> -79.8451302
# ....
# Nombre> iglesiaevangélicaapostólicadelnombredejesús
# Lugar> Iglesia Evangélica Apostólica del Nombre de Jesús
# Tipo> Iglesia
# Latitud> -2.167219
# Longitud> -79.836666
# ....
# Nombre> elshaddaiiglesiacristiana
# Lugar> El Shaddai Iglesia Cristiana
# Tipo> Iglesia
# Latitud> -2.1692821
# Longitud> -79.8357102
# ....
# Nombre> parroquia5dejuniodurán
# Lugar> Parroquia 5 de Junio Durán
# Tipo> Iglesia
# Latitud> -2.169409
# Longitud> -79.8290343
# ....
# Nombre> iglesiacatólicasangabrielarcángel-durán
# Lugar> Iglesia Católica San Gabriel Arcángel - Durán
# Tipo> Iglesia
# Latitud> -2.169409
# Longitud> -79.8290343
# ....
# Nombre> localiglesiadediosenduran
# Lugar> Local Iglesia de Dios en Duran
# Tipo> Iglesia
# Latitud> -2.1776135
# Longitud> -79.8288279
# ....
# Nombre> parroquiajesúsdelgranpoder
# Lugar> Parroquia Jesús del Gran Poder
# Tipo> Iglesia
# Latitud> -2.1787814
# Longitud> -79.8453193
# ....
# Nombre> asambleadeiglesiascristianascentral
# Lugar> Asamblea de Iglesias Cristianas Central
# Tipo> Iglesia
# Latitud> -2.182453
# Longitud> -79.8448294
# ....
# Nombre> iglesiaadventistadel7modialoshelechos
# Lugar> Iglesia Adventista Del 7mo Dia Los Helechos
# Tipo> Iglesia
# Latitud> -2.182453
# Longitud> -79.8448294
# ....
# Nombre> concatedralsantuariocatólicodivinoniño
# Lugar> Concatedral Santuario Católico Divino Niño
# Tipo> Iglesia
# Latitud> -2.1685686
# Longitud> -79.8360094
# ....
# Nombre> iglesiaduran
# Lugar> Iglesia duran
# Tipo> Iglesia
# Latitud> -2.1893597
# Longitud> -79.8535349
# ....
# Nombre> iglesiamdsdurán
# Lugar> Iglesia MDS Durán
# Tipo> Iglesia
# Latitud> -2.1820205
# Longitud> -79.8538967
# ....
# Nombre> estacióndelaaeroviadurán
# Lugar> Estación de la aerovia Durán
# Tipo> Transporte
# Latitud> -2.1874636
# Longitud> -79.8589169
# ....
# Nombre> aerovíadurán
# Lugar> AEROVÍA DURÁN
# Tipo> Transporte
# Latitud> -2.1868536
# Longitud> -79.8591039
# ....
# Nombre> coopdetransportepresidenteeloyalfaro
# Lugar> Coop De Transporte PRESIDENTE Eloy Alfaro
# Tipo> Transporte
# Latitud> -2.1781879
# Longitud> -79.8551869
# ....
# Nombre> terminalterrestrededurán"luisrodastoral"
# Lugar> "Terminal Terrestre de Durán ""Luis Rodas Toral"""
# Tipo> Transporte
# Latitud> -2.1788166
# Longitud> -79.8243425
# ....
# Nombre> cooperativadetransportesecuador
# Lugar> Cooperativa De Transportes Ecuador
# Tipo> Transporte
# Latitud> -2.1783624
# Longitud> -79.8239815
# ....
# Nombre> cooperativasmariscalsucretranss.a.n.
# Lugar> Cooperativas Mariscal Sucre Trans S.A.N.
# Tipo> Transporte
# Latitud> -2.1783624
# Longitud> -79.8239815
# ....
# Nombre> cooperativadetransporterircay
# Lugar> COOPERATIVA DE TRANSPORTE RIRCAY
# Tipo> Transporte
# Latitud> -2.1783624
# Longitud> -79.8239815
# ....
# Nombre> medigroup
# Lugar> Medigroup
# Tipo> Hospital
# Latitud> -2.1797415
# Longitud> -79.8256751
# ....
# Nombre> centrodesaludtipocelrecreo
# Lugar> Centro de Salud Tipo C El Recreo
# Tipo> Hospital
# Latitud> -2.1750525
# Longitud> -79.8071282
# ....
# Nombre> clinicamoreno
# Lugar> Clinica Moreno
# Tipo> Hospital
# Latitud> -2.1750525
# Longitud> -79.8071282
# ....
# Nombre> hospitalgeneralde120camas-durán
# Lugar> Hospital General De 120 Camas - Durán
# Tipo> Hospital
# Latitud> -2.1886777
# Longitud> -79.8303695
# ....

# %%
results1 = []
with open('relaciones.csv') as File:
    reader = csv.DictReader(File)
    for row in reader:
        results1.append(row)
    #print(results)
for ite in results1:
    ro = ite['Origen;Distanciakm;Recorridokm;Destino']
    arr = ro.split(sep=';')
    print('Origen> '+arr[0])
    print('Distanciakm> '+arr[1])
    print('Recorridokm> '+arr[2])
    print('Destino> '+arr[3])
    
    print("....")
# Out:
# Origen> parquesanjose
# Distanciakm> 0.25203
# Recorridokm> 0.55
# Destino> parquecdla.modular
# ....
# Origen> parquesanjose
# Distanciakm> 1.9
# Recorridokm> 2.3
# Destino> parquecdla.16deoctubre
# ....
# Origen> parquesanjose
# Distanciakm> 1.96
# Recorridokm> 2.8
# Destino> parqueacuaticoheroesnacionales
# ....
# Origen> parquecdla.16deoctubre
# Distanciakm> 2.79
# Recorridokm> 3.5
# Destino> parquedelaprimavera1
# ....
# Origen> parquecdla.16deoctubre
# Distanciakm> 3.2
# Recorridokm> 4
# Destino> parquerecreacionalcdla.rioguayas
# ....
# Origen> parquecdla.16deoctubre
# Distanciakm> 2.54
# Recorridokm> 5.2
# Destino> parquealamadre
# ....
# Origen> parqueacuaticoheroesnacionales
# Distanciakm> 1.31
# Recorridokm> 1.8
# Destino> parquedelaprimavera1
# ....
# Origen> parqueacuaticoheroesnacionales
# Distanciakm> 1.96
# Recorridokm> 2.3
# Destino> parquerecreacionalcdla.rioguayas
# ....
# Origen> parquedelaprimavera1
# Distanciakm> 0.2
# Recorridokm> 0.7
# Destino> parquerecreacionalcdla.rioguayas
# ....
# Origen> parquedelaprimavera1
# Distanciakm> 1.29
# Recorridokm> 2.1
# Destino> parquealamadre
# ....
# Origen> parquerecreacionalcdla.rioguayas
# Distanciakm> 0.98
# Recorridokm> 1.5
# Destino> parquealamadre
# ....
# Origen> parquerecreacionalcdla.rioguayas
# Distanciakm> 1.22
# Recorridokm> 2.4
# Destino> parquecolinasdelvalle
# ....
# Origen> parquealamadre
# Distanciakm> 0.8
# Recorridokm> 2.2
# Destino> parquecolinasdelvalle
# ....
# Origen> parquealamadre
# Distanciakm> 1.38
# Recorridokm> 2.5
# Destino> parqueprimavera
# ....
# Origen> parquecolinasdelvalle
# Distanciakm> 0.58
# Recorridokm> 0.85
# Destino> parqueprimavera
# ....
# Origen> parquecolinasdelvalle
# Distanciakm> 0.5
# Recorridokm> 2.1
# Destino> skatemunicipaldeduranprima.2
# ....
# Origen> parqueprimavera
# Distanciakm> 0.33
# Recorridokm> 0.45
# Destino> skatemunicipaldeduranprima.2
# ....
# Origen> parqueprimavera
# Distanciakm> 0.4
# Recorridokm> 0.95
# Destino> parqueecologicoduran
# ....
# Origen> skatemunicipaldeduranprima.2
# Distanciakm> 0.79
# Recorridokm> 0.8
# Destino> parqueecologicoduran
# ....
# Origen> skatemunicipaldeduranprima.2
# Distanciakm> 0.35
# Recorridokm> 0.5
# Destino> parqueprimavera2
# ....
# Origen> parqueecologicoduran
# Distanciakm> 0.91
# Recorridokm> 1.6
# Destino> parqueprimavera2
# ....
# Origen> parqueecologicoduran
# Distanciakm> 6.63
# Recorridokm> 9.6
# Destino> canteracerrogrande
# ....
# Origen> parqueprimavera2
# Distanciakm> 5.69
# Recorridokm> 10.7
# Destino> canteracerrogrande
# ....
# Origen> parqueprimavera2
# Distanciakm> 5.24
# Recorridokm> 8.9
# Destino> primerparque4taet.recreo
# ....
# Origen> canteracerrogrande
# Distanciakm> 1.3
# Recorridokm> 2.2
# Destino> primerparque4taet.recreo
# ....
# Origen> canteracerrogrande
# Distanciakm> 0.96
# Recorridokm> 2.3
# Destino> canchasdeindor
# ....
# Origen> primerparque4taet.recreo
# Distanciakm> 0.05
# Recorridokm> 0.07
# Destino> canchasdeindor
# ....
# Origen> primerparque4taet.recreo
# Distanciakm> 0.78
# Recorridokm> 0.9
# Destino> parquedela5taetapa
# ....
# Origen> canchasdeindor
# Distanciakm> 0.75
# Recorridokm> 0.9
# Destino> parquedela5taetapa
# ....
# Origen> canchasdeindor
# Distanciakm> 4.08
# Recorridokm> 5.6
# Destino> parqueacuaticoheroesnacionales
# ....
# Origen> parquedela5taetapa
# Distanciakm> 3.41
# Recorridokm> 4.7
# Destino> parqueacuaticoheroesnacionales
# ....
# Origen> parquedela5taetapa
# Distanciakm> 5.32
# Recorridokm> 9.1
# Destino> areasverdes
# ....
# Origen> parqueacuaticoheroesnacionales
# Distanciakm> 2.98
# Recorridokm> 3.7
# Destino> areasverdes
# ....
# Origen> parqueacuaticoheroesnacionales
# Distanciakm> 2.92
# Recorridokm> 3.5
# Destino> parque
# ....
# Origen> areasverdes
# Distanciakm> 0.1
# Recorridokm> 0.15
# Destino> parque
# ....
# Origen> areasverdes
# Distanciakm> 1.37
# Recorridokm> 2.1
# Destino> hotellaríadurán
# ....
# Origen> parque
# Distanciakm> 1.24
# Recorridokm> 2
# Destino> hotellaríadurán
# ....
# Origen> parque
# Distanciakm> 5.06
# Recorridokm> 7.5
# Destino> iglesiadediosduran
# ....
# Origen> hotellaríadurán
# Distanciakm> 1.29
# Recorridokm> 2.1
# Destino> iglesiadediosduran
# ....
# Origen> hotellaríadurán
# Distanciakm> 3.64
# Recorridokm> 6.5
# Destino> iglesiacatólicasantamaríareinadelasfamilias
# ....
# Origen> iglesiadediosduran
# Distanciakm> 3.12
# Recorridokm> 5
# Destino> iglesiacatólicasantamaríareinadelasfamilias
# ....
# Origen> iglesiadediosduran
# Distanciakm> 1.46
# Recorridokm> 1.9
# Destino> laiglesiadejesucristosudcapillaponton
# ....
# Origen> iglesiacatólicasantamaríareinadelasfamilias
# Distanciakm> 3.88
# Recorridokm> 5.8
# Destino> laiglesiadejesucristosudcapillaponton
# ....
# Origen> iglesiacatólicasantamaríareinadelasfamilias
# Distanciakm> 3.48
# Recorridokm> 7
# Destino> "iglesiaevangelica""laresurreccion"""
# ....
# Origen> laiglesiadejesucristosudcapillaponton
# Distanciakm> 1.8
# Recorridokm> 2.4
# Destino> "iglesiaevangelica""laresurreccion"""
# ....
# Origen> laiglesiadejesucristosudcapillaponton
# Distanciakm> 1.88
# Recorridokm> 3.8
# Destino> iglesiaevangélicaatriosdealabanzas
# ....
# Origen> iglesiaevangelica"laresurreccion"
# Distanciakm> 1
# Recorridokm> 1.2
# Destino> iglesiaevangélicaatriosdealabanzas
# ....
# Origen> iglesiaevangelica"laresurreccion"
# Distanciakm> 2.33
# Recorridokm> 3
# Destino> iglesiacatólicainmaculadaconcepción
# ....
# Origen> iglesiaevangélicaatriosdealabanzas
# Distanciakm> 2.17
# Recorridokm> 3.3
# Destino> iglesiacatólicainmaculadaconcepción
# ....
# Origen> iglesiaevangélicaatriosdealabanzas
# Distanciakm> 1.82
# Recorridokm> 3.3
# Destino> iglesiaevangélicaapostólicadelnombredejesús
# ....
# Origen> iglesiacatólicainmaculadaconcepción
# Distanciakm> 0.44
# Recorridokm> 0.55
# Destino> iglesiaevangélicaapostólicadelnombredejesús
# ....
# Origen> iglesiacatólicainmaculadaconcepción
# Distanciakm> 0.18
# Recorridokm> 0.4
# Destino> elshaddaiiglesiacristiana
# ....
# Origen> iglesiaevangélicaapostólicadelnombredejesús
# Distanciakm> 0.56
# Recorridokm> 0.8
# Destino> elshaddaiiglesiacristiana
# ....
# Origen> iglesiaevangélicaapostólicadelnombredejesús
# Distanciakm> 0.5
# Recorridokm> 1.6
# Destino> parroquia5dejuniodurán
# ....
# Origen> elshaddaiiglesiacristiana
# Distanciakm> 1.49
# Recorridokm> 2.5
# Destino> parroquia5dejuniodurán
# ....
# Origen> elshaddaiiglesiacristiana
# Distanciakm> 1.98
# Recorridokm> 3
# Destino> iglesiacatólicasangabrielarcángel-durán
# ....
# Origen> parroquia5dejuniodurán
# Distanciakm> 541.59
# Recorridokm> 1.1
# Destino> iglesiacatólicasangabrielarcángel-durán
# ....
# Origen> parroquia5dejuniodurán
# Distanciakm> 0.94
# Recorridokm> 1.5
# Destino> localiglesiadediosenduran
# ....
# Origen> iglesiacatólicasangabrielarcángel-durán
# Distanciakm> 0.78
# Recorridokm> 1.1
# Destino> localiglesiadediosenduran
# ....
# Origen> iglesiacatólicasangabrielarcángel-durán
# Distanciakm> 2.18
# Recorridokm> 4.6
# Destino> parroquiajesúsdelgranpoder
# ....
# Origen> localiglesiadediosenduran
# Distanciakm> 2.72
# Recorridokm> 4.1
# Destino> parroquiajesúsdelgranpoder
# ....
# Origen> localiglesiadediosenduran
# Distanciakm> 3.11
# Recorridokm> 4.7
# Destino> asambleadeiglesiascristianascentral
# ....
# Origen> parroquiajesúsdelgranpoder
# Distanciakm> 0.43
# Recorridokm> 0.7
# Destino> asambleadeiglesiascristianascentral
# ....
# Origen> parroquiajesúsdelgranpoder
# Distanciakm> 0.53
# Recorridokm> 0.7
# Destino> iglesiaadventistadel7modialoshelechos
# ....
# Origen> asambleadeiglesiascristianascentral
# Distanciakm> 0.13
# Recorridokm> 0.16
# Destino> iglesiaadventistadel7modialoshelechos
# ....
# Origen> asambleadeiglesiascristianascentral
# Distanciakm> 1.74
# Recorridokm> 3.8
# Destino> concatedralsantuariocatólicodivinoniño
# ....
# Origen> iglesiaadventistadel7modialoshelechos
# Distanciakm> 1.79
# Recorridokm> 4.5
# Destino> concatedralsantuariocatólicodivinoniño
# ....
# Origen> iglesiaadventistadel7modialoshelechos
# Distanciakm> 1.07
# Recorridokm> 1.6
# Destino> iglesiamdsdurán
# ....
# Origen> concatedralsantuariocatólicodivinoniño
# Distanciakm> 2.47
# Recorridokm> 3.6
# Destino> iglesiamdsdurán
# ....
# Origen> concatedralsantuariocatólicodivinoniño
# Distanciakm> 3.31
# Recorridokm> 5.7
# Destino> estacióndelaaeroviadurán
# ....
# Origen> iglesiamdsdurán
# Distanciakm> 0.92
# Recorridokm> 2.1
# Destino> estacióndelaaeroviadurán
# ....
# Origen> iglesiamdsdurán
# Distanciakm> 0.86
# Recorridokm> 1.1
# Destino> aerovíadurán
# ....
# Origen> estacióndelaaeroviadurán
# Distanciakm> 0.14
# Recorridokm> 2.4
# Destino> aerovíadurán
# ....
# Origen> estacióndelaaeroviadurán
# Distanciakm> 1.2
# Recorridokm> 1.6
# Destino> coopdetransportepresidenteeloyalfaro
# ....
# Origen> aerovíadurán
# Distanciakm> 1.16
# Recorridokm> 1.3
# Destino> coopdetransportepresidenteeloyalfaro
# ....
# Origen> aerovíadurán
# Distanciakm> 3.74
# Recorridokm> 5.7
# Destino> "terminalterrestrededurán""luisrodastoral"""
# ....
# Origen> coopdetransportepresidenteeloyalfaro
# Distanciakm> 3.42
# Recorridokm> 4.8
# Destino> "terminalterrestrededurán""luisrodastoral"""
# ....
# Origen> coopdetransportepresidenteeloyalfaro
# Distanciakm> 3.47
# Recorridokm> 5
# Destino> cooperativadetransportesecuador
# ....
# Origen> terminalterrestrededurán"luisrodastoral"
# Distanciakm> 0.11
# Recorridokm> 0.27
# Destino> cooperativadetransportesecuador
# ....
# Origen> terminalterrestrededurán"luisrodastoral"
# Distanciakm> 0.14
# Recorridokm> 0.3
# Destino> cooperativasmariscalsucretranss.a.n.
# ....
# Origen> cooperativadetransportesecuador
# Distanciakm> 0.03
# Recorridokm> 0.03
# Destino> cooperativasmariscalsucretranss.a.n.
# ....
# Origen> cooperativadetransportesecuador
# Distanciakm> 0.01
# Recorridokm> 0.01
# Destino> cooperativadetransporterircay
# ....
# Origen> cooperativasmariscalsucretranss.a.n.
# Distanciakm> 0.14
# Recorridokm> 0.29
# Destino> cooperativadetransporterircay
# ....
# Origen> cooperativasmariscalsucretranss.a.n.
# Distanciakm> 0.36
# Recorridokm> 2.1
# Destino> medigroup
# ....
# Origen> cooperativadetransporterircay
# Distanciakm> 0.3
# Recorridokm> 2.4
# Destino> medigroup
# ....
# Origen> cooperativadetransporterircay
# Distanciakm> 1.96
# Recorridokm> 3.5
# Destino> centrodesaludtipocelrecreo
# ....
# Origen> medigroup
# Distanciakm> 1.96
# Recorridokm> 3.1
# Destino> centrodesaludtipocelrecreo
# ....
# Origen> medigroup
# Distanciakm> 2.59
# Recorridokm> 3.4
# Destino> clinicamoreno
# ....
# Origen> centrodesaludtipocelrecreo
# Distanciakm> 0.29
# Recorridokm> 0.4
# Destino> clinicamoreno
# ....
# Origen> centrodesaludtipocelrecreo
# Distanciakm> 2.85
# Recorridokm> 4.9
# Destino> hospitalgeneralde120camas-durán
# ....
# Origen> clinicamoreno
# Distanciakm> 3.09
# Recorridokm> 4.9
# Destino> hospitalgeneralde120camas-durán
# ....
